# %% [markdown]
# # Data Cleaning: Car Details Dataset

# %% [markdown]
# ## 1. Importing Libarries

# %%
import numpy as np
import pandas as pd
from IPython.display import HTML, display

# %% [markdown]
# ## 2. Reading in the Dataset

# %%
path = r"E:\sagemaker-flight-prices-prediction\optuna\Car details v3.csv"

df = pd.read_csv(path)
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
- Data has 8128 observations and 13 features
- Data utilizes about 5 mb of memory
- Some features have missing rows
- from name, we can separate name and model 
- mileage, engine, max_power, torque dtype to be changed to integer datatype
- torque can be divided into torque and rpm

# %% [markdown]
# ## Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 1202

# %%
df.duplicated(subset="name").sum()
# Out:
# 6070

# %%
(
    df
    .loc[df.duplicated(subset = ["name", "year"], keep=False)]
    .sort_values("name")

)
# Out:
#                                 name  year  selling_price  km_driven    fuel  \
# 7747                 Audi A4 2.0 TDI  2014        1500000      60000  Diesel
# 906                  Audi A4 2.0 TDI  2014        1600000      44000  Diesel
# 7374     Audi A4 35 TDI Premium Plus  2016        2450000      30000  Diesel
# 5261     Audi A4 35 TDI Premium Plus  2016        1898999      46000  Diesel
# 4951          Audi A6 35 TFSI Matrix  2019        5923000      11500  Petrol
# ...                              ...   ...            ...        ...     ...
# 3520  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 374   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 6213  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 3251          Volvo XC40 D4 R-Design  2018        3400000      22000  Diesel
# 145           Volvo XC40 D4 R-Design  2018        3400000      22000  Diesel
#
#      seller_type transmission           owner     mileage   engine  \
# 7747  Individual    Automatic     First Owner  16.55 kmpl  1968 CC
# 906   Individual    Automatic    Second Owner  16.55 kmpl  1968 CC
# 7374      Dealer    Automatic     First Owner  18.25 kmpl  1968 CC
# 5261      Dealer    Automatic     First Owner  18.25 kmpl  1968 CC
# 4951      Dealer    Automatic  Test Drive Car  15.26 kmpl  1798 CC
# ...          ...          ...             ...         ...      ...
# 3520  Individual    Automatic     First Owner   18.0 kmpl  1969 CC
# 374   Individual    Automatic     First Owner   18.0 kmpl  1969 CC
# 6213  Individual    Automatic     First Owner   18.0 kmpl  1969 CC
# 3251      Dealer    Automatic     First Owner   18.0 kmpl  1969 CC
# 145       Dealer    Automatic     First Owner   18.0 kmpl  1969 CC
#
#        max_power               torque  seats
# 7747  147.51 bhp  320Nm@ 1750-2500rpm    5.0
# 906   147.51 bhp  320Nm@ 1750-2500rpm    5.0
# 7374  187.74 bhp  400Nm@ 1750-3000rpm    5.0
# 5261  187.74 bhp  400Nm@ 1750-3000rpm    5.0
# 4951  187.74 bhp  320Nm@ 1400-4100rpm    5.0
# ...          ...                  ...    ...
# 3520     190 bhp                400Nm    5.0
# 374      190 bhp                400Nm    5.0
# 6213     190 bhp                400Nm    5.0
# 3251     190 bhp                400Nm    5.0
# 145      190 bhp                400Nm    5.0
#
# [5894 rows x 13 columns]

# %%
- The 1202 duplicate entries should be deleted from the dataset
- There're some vehicles of the same name, but these differ w.r.t. other features and can be considered valid entries

# %% [markdown]
# ## Column-wise Inspection

# %% [markdown]
# ### name

# %%
df.name
# Out:
# 0             Maruti Swift Dzire VDI
# 1       Skoda Rapid 1.5 TDI Ambition
# 2           Honda City 2017-2020 EXi
# 3          Hyundai i20 Sportz Diesel
# 4             Maruti Swift VXI BSIII
#                     ...
# 8123               Hyundai i20 Magna
# 8124           Hyundai Verna CRDi SX
# 8125          Maruti Swift Dzire ZDi
# 8126                 Tata Indigo CR4
# 8127                 Tata Indigo CR4
# Name: name, Length: 8128, dtype: object

# %%
df.name.dtype
# Out:
# dtype('O')

# %%
(
    df
    .name
    .str.split(" ", n=2, expand=True)
    .set_axis(["company", "model", "edition"], axis=1)
)
# Out:
#       company   model           edition
# 0      Maruti   Swift         Dzire VDI
# 1       Skoda   Rapid  1.5 TDI Ambition
# 2       Honda    City     2017-2020 EXi
# 3     Hyundai     i20     Sportz Diesel
# 4      Maruti   Swift         VXI BSIII
# ...       ...     ...               ...
# 8123  Hyundai     i20             Magna
# 8124  Hyundai   Verna           CRDi SX
# 8125   Maruti   Swift         Dzire ZDi
# 8126     Tata  Indigo               CR4
# 8127     Tata  Indigo               CR4
#
# [8128 rows x 3 columns]

# %%
(
    df
    .pipe(lambda df_:
                     pd.concat([
                                 df_
                                 .name
                                 .str.split(" ", n=2, expand=True)
                                 .set_axis(["company", "model", "edition"], axis=1),
                                 df_], axis=1
                     ))

)
# Out:
#       company   model           edition                          name  year  \
# 0      Maruti   Swift         Dzire VDI        Maruti Swift Dzire VDI  2014
# 1       Skoda   Rapid  1.5 TDI Ambition  Skoda Rapid 1.5 TDI Ambition  2014
# 2       Honda    City     2017-2020 EXi      Honda City 2017-2020 EXi  2006
# 3     Hyundai     i20     Sportz Diesel     Hyundai i20 Sportz Diesel  2010
# 4      Maruti   Swift         VXI BSIII        Maruti Swift VXI BSIII  2007
# ...       ...     ...               ...                           ...   ...
# 8123  Hyundai     i20             Magna             Hyundai i20 Magna  2013
# 8124  Hyundai   Verna           CRDi SX         Hyundai Verna CRDi SX  2007
# 8125   Maruti   Swift         Dzire ZDi        Maruti Swift Dzire ZDi  2009
# 8126     Tata  Indigo               CR4               Tata Indigo CR4  2013
# 8127     Tata  Indigo               CR4               Tata Indigo CR4  2013
#
#       selling_price  km_driven    fuel seller_type transmission  \
# 0            450000     145500  Diesel  Individual       Manual
# 1            370000     120000  Diesel  Individual       Manual
# 2            158000     140000  Petrol  Individual       Manual
# 3            225000     127000  Diesel  Individual       Manual
# 4            130000     120000  Petrol  Individual       Manual
# ...             ...        ...     ...         ...          ...
# 8123         320000     110000  Petrol  Individual       Manual
# 8124         135000     119000  Diesel  Individual       Manual
# 8125         382000     120000  Diesel  Individual       Manual
# 8126         290000      25000  Diesel  Individual       Manual
# 8127         290000      25000  Diesel  Individual       Manual
#
#                      owner     mileage   engine   max_power  \
# 0              First Owner   23.4 kmpl  1248 CC      74 bhp
# 1             Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2              Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3              First Owner   23.0 kmpl  1396 CC      90 bhp
# 4              First Owner   16.1 kmpl  1298 CC    88.2 bhp
# ...                    ...         ...      ...         ...
# 8123           First Owner   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Fourth & Above Owner   16.8 kmpl  1493 CC     110 bhp
# 8125           First Owner   19.3 kmpl  1248 CC    73.9 bhp
# 8126           First Owner  23.57 kmpl  1396 CC      70 bhp
# 8127           First Owner  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats
# 0                190Nm@ 2000rpm    5.0
# 1           250Nm@ 1500-2500rpm    5.0
# 2         12.7@ 2,700(kgm@ rpm)    5.0
# 3      22.4 kgm at 1750-2750rpm    5.0
# 4         11.5@ 4,500(kgm@ rpm)    5.0
# ...                         ...    ...
# 8123           113.7Nm@ 4000rpm    5.0
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125             190Nm@ 2000rpm    5.0
# 8126        140Nm@ 1800-3000rpm    5.0
# 8127        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 16 columns]

# %% [markdown]
# ## year

# %%
df.year
# Out:
# 0       2014
# 1       2014
# 2       2006
# 3       2010
# 4       2007
#         ...
# 8123    2013
# 8124    2007
# 8125    2009
# 8126    2013
# 8127    2013
# Name: year, Length: 8128, dtype: int64

# %%
df.year.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Observations:
# - The column is of the right datatype
# - The values seem to be valid and accurate
# - No further cleaning steps required

# %% [markdown]
# ## selling_price

# %%
df.selling_price
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 8128, dtype: int64

# %%
df.selling_price.describe()
# Out:
# count    8.128000e+03
# mean     6.382718e+05
# std      8.062534e+05
# min      2.999900e+04
# 25%      2.549990e+05
# 50%      4.500000e+05
# 75%      6.750000e+05
# max      1.000000e+07
# Name: selling_price, dtype: float64

# %% [markdown]
# Observations:
# - The column is of the right datatype
# - The values seem to be valid
# - No further cleaning steps required
# - This could be treated as the target feature for predictive modelling

# %% [markdown]
# ## km_driven

# %%
df.km_driven
# Out:
# 0       145500
# 1       120000
# 2       140000
# 3       127000
# 4       120000
#          ...
# 8123    110000
# 8124    119000
# 8125    120000
# 8126     25000
# 8127     25000
# Name: km_driven, Length: 8128, dtype: int64

# %%
df.km_driven.describe()
# Out:
# count    8.128000e+03
# mean     6.981951e+04
# std      5.655055e+04
# min      1.000000e+00
# 25%      3.500000e+04
# 50%      6.000000e+04
# 75%      9.800000e+04
# max      2.360457e+06
# Name: km_driven, dtype: float64

# %% [markdown]
# Observations:
# - The column is of the right datatype
# - The values seem to be valid
# - No further cleaning steps required

# %% [markdown]
# ## fuel

# %%
df.fuel
# Out:
# 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# 8126    Diesel
# 8127    Diesel
# Name: fuel, Length: 8128, dtype: object

# %%
df.fuel.unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df.fuel.value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df.fuel.value_counts(normalize=True)
# Out:
# fuel
# Diesel    0.541585
# Petrol    0.446727
# CNG       0.007013
# LPG       0.004675
# Name: proportion, dtype: float64

# %%
df.fuel.memory_usage(deep=True)
# Out:
# 511911

# %%
(
    df
    .fuel
    .astype("category")
    )
# Out:
# 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# 8126    Diesel
# 8127    Diesel
# Name: fuel, Length: 8128, dtype: category
# Categories (4, object): ['CNG', 'Diesel', 'LPG', 'Petrol']

# %%
(
    df
    .fuel
    .astype("category")
    .memory_usage(deep=True)
    )
# Out:
# 8678

# %%
# By changing the categorical column fromObject to Category dtype, space consumption came down.

# %%
(df
 .fuel
 .value_counts()
 .pipe(lambda ser: pd.concat([ser, df.fuel
                                     .value_counts(normalize=True)],
                             axis=1)))
# Out:
#         count  proportion
# fuel
# Diesel   4402    0.541585
# Petrol   3631    0.446727
# CNG        57    0.007013
# LPG        38    0.004675

# %%
(df
 .loc[df.fuel.isin(["Diesel", "Petrol"])]
 .mileage
 .str.split(" ")
 .str[1]
 .unique())
# Out:
# array(['kmpl', nan], dtype=object)

# %%
(df
 .loc[df.fuel.isin(["CNG", "LPG"])]
 .mileage
 .str.split(" ")
 .str[1]
 .unique())
# Out:
# array(['km/kg', nan], dtype=object)

# %% [markdown]
# Observations:
# - fuel has 4 unique values
# - Occupies about 511,900 bytes of memory
# - CNG and LPG account for only 0.7% and 0.5% of the total observations respectively
# - Vehicles operating on CNG and LPG have their mileage units in km\kg whereas those running on Petrol and Diesel have mileage measured on kmpl

# %% [markdown]
# Steps:
# - The datatype could be converted to category for optimizing memory usage (about 60 times less) since the cardinality is very less
# - CNG and LPG only account for 1.2% of total observations collectively, whether to drop these rows could be decided on further exploratory analysis

# %% [markdown]
# ## seller_type

# %%
df.seller_type
# Out:
# 0       Individual
# 1       Individual
# 2       Individual
# 3       Individual
# 4       Individual
#            ...
# 8123    Individual
# 8124    Individual
# 8125    Individual
# 8126    Individual
# 8127    Individual
# Name: seller_type, Length: 8128, dtype: object

# %%
df.seller_type.memory_usage(deep=True)
# Out:
# 541620

# %%
df.seller_type.unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
(
    df
    .seller_type
    .astype("category")
    .memory_usage(deep=True))
# Out:
# 8571

# %%
(
    df
    .seller_type
    .value_counts())
# Out:
# seller_type
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: count, dtype: int64

# %%
(
    df
    .seller_type
    .value_counts()
    .pipe(lambda ser:
                     pd.concat([ser, df.seller_type.value_counts(normalize=True)], axis=1)))
# Out:
#                   count  proportion
# seller_type
# Individual         6766    0.832431
# Dealer             1126    0.138533
# Trustmark Dealer    236    0.029035

# %%
df.loc[df.seller_type=="Trustmark Dealer"].head()
# Out:
#                                        name  year  selling_price  km_driven  \
# 375                 Toyota Camry 2.5 Hybrid  2016        2000000      68089
# 376                      Maruti Wagon R LXI  2013         225000      58343
# 378                           Honda Jazz VX  2016         550000      56494
# 379  Toyota Innova 2.5 VX (Diesel) 7 Seater  2013         750000      79328
# 380                Maruti Swift AMT VVT VXI  2019         650000       5621
#
#        fuel       seller_type transmission         owner     mileage   engine  \
# 375  Petrol  Trustmark Dealer    Automatic   First Owner  19.16 kmpl  2494 CC
# 376  Petrol  Trustmark Dealer       Manual   First Owner  21.79 kmpl   998 CC
# 378  Petrol  Trustmark Dealer       Manual   First Owner   18.2 kmpl  1199 CC
# 379  Diesel  Trustmark Dealer       Manual  Second Owner  12.99 kmpl  2494 CC
# 380  Petrol  Trustmark Dealer    Automatic   First Owner   22.0 kmpl  1197 CC
#
#      max_power               torque  seats
# 375  157.7 bhp       213Nm@ 4500rpm    5.0
# 376  67.05 bhp        90Nm@ 3500rpm    5.0
# 378   88.7 bhp       110Nm@ 4800rpm    5.0
# 379  100.6 bhp  200Nm@ 1200-3600rpm    7.0
# 380  81.80 bhp       113Nm@ 4200rpm    5.0

# %%
(df
 .loc[df.seller_type == "Trustmark Dealer"]
 .mileage
 .str.split(" ")
 .str[1]
 .unique())
# Out:
# array(['kmpl'], dtype=object)

# %%
(df
 .loc[df.seller_type == "Individual"]
 .mileage
 .str.split(" ")
 .str[1]
 .unique())
# Out:
# array(['kmpl', 'km/kg', nan], dtype=object)

# %%
(df
 .loc[df.seller_type == "Dealer"]
 .mileage
 .str.split(" ")
 .str[1]
 .unique())
# Out:
# array(['kmpl', nan, 'km/kg'], dtype=object)

# %% [markdown]
# Observations:
# - seller_type has 3 unique values
# - Occupies about 541,600 bytes of memory
# - Vehicles of Trustmark Dealer have their mileages measured in kmpl
# - Cardinality is less
# Steps:
# - The datatype could be converted to category for optimizing memory usage (about 63 times) since the cardinality is very less

# %% [markdown]
# ## transmission

# %%
df.transmission
# Out:
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual
#          ...
# 8123    Manual
# 8124    Manual
# 8125    Manual
# 8126    Manual
# 8127    Manual
# Name: transmission, Length: 8128, dtype: object

# %%
df.transmission.memory_usage(deep=True)
# Out:
# 515346

# %%
df.transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
(
    df
    .transmission
    .astype("category")
    .memory_usage(deep=True))
# Out:
# 8497

# %%
(
    df
    .transmission
    .value_counts()
    .pipe(lambda ser:
                     pd.concat([ser, df.transmission.value_counts(normalize=True)], axis=1)))
# Out:
#               count  proportion
# transmission
# Manual         7078    0.870817
# Automatic      1050    0.129183

# %% [markdown]
# Observations:
# - transmission has 2 unique values
# - Occupies about 515,342 bytes of memory
# - Cardinality is less
# Steps:
# - The datatype could be converted to category for optimizing memory usage (about 61 times less) since the cardinality is very less

# %% [markdown]
# ## owner

# %%
df.owner
# Out:
# 0                First Owner
# 1               Second Owner
# 2                Third Owner
# 3                First Owner
# 4                First Owner
#                 ...
# 8123             First Owner
# 8124    Fourth & Above Owner
# 8125             First Owner
# 8126             First Owner
# 8127             First Owner
# Name: owner, Length: 8128, dtype: object

# %%
df.owner.memory_usage(deep=True)
# Out:
# 556522

# %%
df.owner.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
(
    df
    .owner
    .astype("category")
    .memory_usage(deep=True))
# Out:
# 8497

# %%
(
    df
    .owner
    .value_counts()
    .pipe(lambda ser:
                     pd.concat([ser, df.owner.value_counts(normalize=True)], axis=1)))
# Out:
#                       count  proportion
# owner
# First Owner            5289    0.650714
# Second Owner           2105    0.258981
# Third Owner             555    0.068282
# Fourth & Above Owner    174    0.021407
# Test Drive Car            5    0.000615

# %% [markdown]
# Observations:
# - There're 5 unique values
# - The cardinality is less
# - This column occupies about 556,518 bytes of memory
# - Test Drive Car accounts for only 0.1% of the total observations
# Steps:
# - The word Owner could be stripped off from the categories as it seems redundant
# - The datatype could be converted to category for optimizing memory usage (about 63 times less) since the cardinality is very less

# %% [markdown]
# ## mileage

# %%
df.mileage
# Out:
# 0        23.4 kmpl
# 1       21.14 kmpl
# 2        17.7 kmpl
# 3        23.0 kmpl
# 4        16.1 kmpl
#            ...
# 8123     18.5 kmpl
# 8124     16.8 kmpl
# 8125     19.3 kmpl
# 8126    23.57 kmpl
# 8127    23.57 kmpl
# Name: mileage, Length: 8128, dtype: object

# %%
(
    df
    .mileage
    .str.split(" ")
    .str[0]
    .astype(float))
# Out:
# 0       23.40
# 1       21.14
# 2       17.70
# 3       23.00
# 4       16.10
#         ...
# 8123    18.50
# 8124    16.80
# 8125    19.30
# 8126    23.57
# 8127    23.57
# Name: mileage, Length: 8128, dtype: float64

# %%
(
    df
    .mileage
    .str.split(" ")
    .str[1]
    .unique())
# Out:
# array(['kmpl', 'km/kg', nan], dtype=object)

# %%
(
    df
    .mileage
    .str.split(" ")
    .str[0]
    .astype(float)
    .describe())
# Out:
# count    7907.000000
# mean       19.418783
# std         4.037145
# min         0.000000
# 25%        16.780000
# 50%        19.300000
# 75%        22.320000
# max        42.000000
# Name: mileage, dtype: float64

# %%
(df
 .dropna()
 .loc[lambda df_: df_.mileage.str.startswith("0")])
# Out:
#                                                    name  year  selling_price  \
# 644   Tata Indica Vista Aura Safire Anniversary Edition  2009         135000
# 785                              Hyundai Santro Xing GL  2009         120000
# 1649                             Hyundai Santro Xing GL  2008         105000
# 1676                Mercedes-Benz M-Class ML 350 4Matic  2011        1700000
# 2137                    Land Rover Freelander 2 TD4 HSE  2013        1650000
# 2366                       Hyundai Santro Xing (Non-AC)  2010         110000
# 2725                       Hyundai Santro Xing (Non-AC)  2013         184000
# 4527                Mercedes-Benz M-Class ML 350 4Matic  2011        1700000
# 5276                             Hyundai Santro Xing GL  2008         175000
# 5843                        Volkswagen Polo GT TSI BSIV  2014         574000
# 5846                        Volkswagen Polo GT TSI BSIV  2014         575000
# 5900                     Mahindra Bolero Pik-Up FB 1.7T  2020         679000
# 6534                             Hyundai Santro Xing GL  2010         150000
# 6629                    Mahindra Bolero Pik-Up CBC 1.7T  2019         722000
# 6824                             Hyundai Santro Xing GL  2011         150000
# 7002                       Hyundai Santro Xing (Non-AC)  2010         110000
# 7337                      Mercedes-Benz GLC 220d 4MATIC  2017        3300000
#
#       km_driven    fuel seller_type transmission                 owner  \
# 644       28900  Petrol  Individual       Manual          Second Owner
# 785       90000  Petrol  Individual       Manual          Second Owner
# 1649     128000  Petrol  Individual       Manual           First Owner
# 1676     110000  Diesel  Individual    Automatic           Third Owner
# 2137      64788  Diesel      Dealer    Automatic           First Owner
# 2366      80000  Petrol  Individual       Manual          Second Owner
# 2725      15000  Petrol  Individual       Manual           First Owner
# 4527     110000  Diesel  Individual    Automatic           Third Owner
# 5276      40000  Petrol  Individual       Manual           First Owner
# 5843      28080  Petrol      Dealer    Automatic           First Owner
# 5846      28100  Petrol      Dealer    Automatic           First Owner
# 5900       5000  Diesel  Individual       Manual           First Owner
# 6534     110000  Petrol  Individual       Manual           First Owner
# 6629      80000  Diesel  Individual       Manual           First Owner
# 6824      40000  Petrol  Individual       Manual  Fourth & Above Owner
# 7002      80000  Petrol  Individual       Manual          Second Owner
# 7337      60000  Diesel      Dealer    Automatic           First Owner
#
#        mileage   engine   max_power                torque  seats
# 644   0.0 kmpl  1172 CC      65 bhp  9.8@ 3,000(kgm@ rpm)    5.0
# 785   0.0 kmpl  1086 CC      62 bhp       96.1Nm@ 3000rpm    5.0
# 1649  0.0 kmpl  1086 CC      62 bhp       96.1Nm@ 3000rpm    5.0
# 1676  0.0 kmpl  2987 CC     165 bhp        510@ 1600-2400    5.0
# 2137  0.0 kmpl  2179 CC     115 bhp      400 Nm /2000 rpm    5.0
# 2366  0.0 kmpl  1086 CC    62.1 bhp       96.1Nm@ 3000rpm    5.0
# 2725  0.0 kmpl  1086 CC    62.1 bhp       96.1Nm@ 3000rpm    5.0
# 4527  0.0 kmpl  2987 CC     165 bhp        510@ 1600-2400    5.0
# 5276  0.0 kmpl  1086 CC      62 bhp       96.1Nm@ 3000rpm    5.0
# 5843  0.0 kmpl  1197 CC  103.25 bhp   175nm@ 1500-4100rpm    5.0
# 5846  0.0 kmpl  1197 CC  103.25 bhp   175nm@ 1500-4100rpm    5.0
# 5900  0.0 kmpl  2523 CC      70 bhp   200Nm@ 1400-2200rpm    2.0
# 6534  0.0 kmpl  1086 CC      62 bhp       96.1Nm@ 3000rpm    5.0
# 6629  0.0 kmpl  2523 CC      70 bhp   200Nm@ 1400-2200rpm    2.0
# 6824  0.0 kmpl  1086 CC      62 bhp       96.1Nm@ 3000rpm    5.0
# 7002  0.0 kmpl  1086 CC    62.1 bhp       96.1Nm@ 3000rpm    5.0
# 7337  0.0 kmpl  1950 CC     194 bhp        400nm@ 2800rpm    5.0

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
(df
 .mileage
 .isna()
 .sum())
# Out:
# 221

# %%
df.mileage.items()

# %%
for i, value in df.mileage.items():
    print(i, value)
# Out:
# 0 23.4 kmpl
# 1 21.14 kmpl
# 2 17.7 kmpl
# 3 23.0 kmpl
# 4 16.1 kmpl
# 5 20.14 kmpl
# 6 17.3 km/kg
# 7 16.1 kmpl
# 8 23.59 kmpl
# 9 20.0 kmpl
# 10 19.01 kmpl
# 11 17.3 kmpl
# 12 19.3 kmpl
# 13 nan
# 14 18.9 kmpl
# 15 18.15 kmpl
# 16 24.52 kmpl
# 17 23.0 kmpl
# 18 19.7 kmpl
# 19 22.54 kmpl
# 20 21.0 kmpl
# 21 25.5 kmpl
# 22 26.59 kmpl
# 23 21.5 kmpl
# 24 20.3 kmpl
# 25 21.4 kmpl
# 26 24.7 kmpl
# 27 18.2 kmpl
# 28 18.9 kmpl
# 29 16.8 kmpl
# 30 24.3 kmpl
# 31 nan
# 32 14.0 kmpl
# 33 18.6 kmpl
# 34 24.3 kmpl
# 35 33.44 km/kg
# 36 23.95 kmpl
# 37 17.0 kmpl
# 38 20.63 kmpl
# 39 13.93 kmpl
# 40 16.1 kmpl
# 41 16.0 kmpl
# 42 17.8 kmpl
# 43 16.8 kmpl
# 44 18.5 kmpl
# 45 24.3 kmpl
# 46 23.95 kmpl
# 47 12.55 kmpl
# 48 12.99 kmpl
# 49 14.8 kmpl
# 50 24.7 kmpl
# 51 13.5 kmpl
# 52 26.0 kmpl
# 53 20.65 kmpl
# 54 27.3 kmpl
# 55 11.36 kmpl
# 56 12.99 kmpl
# 57 17.68 kmpl
# 58 14.28 kmpl
# 59 18.53 kmpl
# 60 14.84 kmpl
# 61 21.12 kmpl
# 62 20.36 kmpl
# 63 21.27 kmpl
# 64 26.59 kmpl
# 65 18.16 kmpl
# 66 21.4 kmpl
# 67 22.0 kmpl
# 68 25.1 kmpl
# 69 20.51 kmpl
# 70 21.66 kmpl
# 71 24.3 kmpl
# 72 24.3 kmpl
# 73 20.36 kmpl
# 74 25.2 kmpl
# 75 12.55 kmpl
# 76 22.9 kmpl
# 77 16.02 kmpl
# 78 nan
# 79 20.54 kmpl
# 80 12.99 kmpl
# 81 22.77 kmpl
# 82 15.71 kmpl
# 83 23.1 kmpl
# 84 19.02 kmpl
# 85 24.7 kmpl
# 86 24.7 kmpl
# 87 nan
# 88 19.81 kmpl
# 89 14.0 kmpl
# 90 26.2 km/kg
# 91 16.47 kmpl
# 92 19.81 kmpl
# 93 15.04 kmpl
# 94 18.2 kmpl
# 95 18.5 kmpl
# 96 26.59 kmpl
# 97 19.1 kmpl
# 98 19.7 kmpl
# 99 22.54 kmpl
# 100 21.79 kmpl
# 101 18.8 kmpl
# 102 21.21 kmpl
# 103 15.37 kmpl
# 104 21.4 kmpl
# 105 11.79 kmpl
# 106 19.0 kmpl
# 107 17.0 kmpl
# 108 14.3 kmpl
# 109 15.8 kmpl
# 110 15.1 kmpl
# 111 19.09 kmpl
# 112 22.32 kmpl
# 113 21.9 kmpl
# 114 14.53 kmpl
# 115 21.63 kmpl
# 116 24.3 kmpl
# 117 20.85 kmpl
# 118 20.51 kmpl
# 119 nan
# 120 20.45 kmpl
# 121 19.67 kmpl
# 122 23.0 kmpl
# 123 19.3 kmpl
# 124 23.01 kmpl
# 125 23.1 kmpl
# 126 19.7 kmpl
# 127 20.77 kmpl
# 128 17.92 kmpl
# 129 20.77 kmpl
# 130 17.8 kmpl
# 131 17.01 kmpl
# 132 22.37 kmpl
# 133 19.33 kmpl
# 134 9.5 kmpl
# 135 12.83 kmpl
# 136 13.5 kmpl
# 137 22.48 kmpl
# 138 nan
# 139 16.78 kmpl
# 140 14.67 kmpl
# 141 15.0 kmpl
# 142 13.96 kmpl
# 143 18.0 kmpl
# 144 14.28 kmpl
# 145 18.0 kmpl
# 146 12.07 kmpl
# 147 26.21 kmpl
# 148 13.5 kmpl
# 149 10.8 kmpl
# 150 16.3 kmpl
# 151 13.6 kmpl
# 152 17.0 kmpl
# 153 15.04 kmpl
# 154 16.3 kmpl
# 155 14.3 kmpl
# 156 15.04 kmpl
# 157 16.02 kmpl
# 158 14.74 kmpl
# 159 15.6 kmpl
# 160 19.56 kmpl
# 161 23.95 kmpl
# 162 21.21 kmpl
# 163 11.36 kmpl
# 164 21.5 kmpl
# 165 22.69 kmpl
# 166 19.16 kmpl
# 167 18.12 kmpl
# 168 12.1 kmpl
# 169 17.5 kmpl
# 170 42.0 kmpl
# 171 20.54 kmpl
# 172 18.16 kmpl
# 173 20.0 kmpl
# 174 20.4 kmpl
# 175 20.51 kmpl
# 176 18.6 kmpl
# 177 16.1 kmpl
# 178 21.1 kmpl
# 179 18.9 kmpl
# 180 19.44 kmpl
# 181 18.9 kmpl
# 182 19.1 kmpl
# 183 19.1 kmpl
# 184 13.0 kmpl
# 185 21.43 kmpl
# 186 18.5 kmpl
# 187 13.0 kmpl
# 188 18.15 kmpl
# 189 22.95 kmpl
# 190 17.0 kmpl
# 191 17.3 kmpl
# 192 18.9 kmpl
# 193 16.2 kmpl
# 194 20.85 kmpl
# 195 15.3 kmpl
# 196 18.6 kmpl
# 197 28.09 kmpl
# 198 20.3 kmpl
# 199 20.77 kmpl
# 200 nan
# 201 17.4 kmpl
# 202 19.4 kmpl
# 203 26.6 km/kg
# 204 20.85 kmpl
# 205 18.5 kmpl
# 206 nan
# 207 20.51 kmpl
# 208 21.21 kmpl
# 209 24.7 kmpl
# 210 22.0 kmpl
# 211 20.4 kmpl
# 212 17.6 kmpl
# 213 18.5 kmpl
# 214 28.4 kmpl
# 215 20.51 kmpl
# 216 14.53 kmpl
# 217 19.4 kmpl
# 218 21.4 kmpl
# 219 14.1 kmpl
# 220 19.7 kmpl
# 221 25.17 kmpl
# 222 20.63 kmpl
# 223 24.3 kmpl
# 224 20.14 kmpl
# 225 22.74 kmpl
# 226 17.0 kmpl
# 227 17.57 kmpl
# 228 nan
# 229 16.95 kmpl
# 230 17.0 kmpl
# 231 19.49 kmpl
# 232 20.51 kmpl
# 233 12.83 kmpl
# 234 17.21 kmpl
# 235 21.1 kmpl
# 236 19.67 kmpl
# 237 25.17 kmpl
# 238 20.77 kmpl
# 239 15.1 kmpl
# 240 15.37 kmpl
# 241 17.92 kmpl
# 242 13.2 kmpl
# 243 15.1 kmpl
# 244 12.99 kmpl
# 245 23.4 kmpl
# 246 19.0 kmpl
# 247 20.36 kmpl
# 248 23.4 kmpl
# 249 24.52 kmpl
# 250 14.2 kmpl
# 251 18.5 kmpl
# 252 nan
# 253 20.4 kmpl
# 254 19.4 kmpl
# 255 22.54 kmpl
# 256 26.8 kmpl
# 257 17.6 kmpl
# 258 17.3 kmpl
# 259 22.32 kmpl
# 260 23.4 kmpl
# 261 19.3 kmpl
# 262 26.0 kmpl
# 263 19.3 kmpl
# 264 25.4 kmpl
# 265 11.5 kmpl
# 266 27.28 kmpl
# 267 17.97 kmpl
# 268 18.6 kmpl
# 269 20.85 kmpl
# 270 12.8 kmpl
# 271 16.55 kmpl
# 272 19.3 kmpl
# 273 20.4 kmpl
# 274 19.02 kmpl
# 275 22.54 kmpl
# 276 12.05 kmpl
# 277 14.07 kmpl
# 278 27.28 kmpl
# 279 17.57 kmpl
# 280 13.2 kmpl
# 281 19.4 kmpl
# 282 18.9 kmpl
# 283 21.02 kmpl
# 284 19.7 kmpl
# 285 11.57 kmpl
# 286 13.6 kmpl
# 287 13.6 kmpl
# 288 17.9 kmpl
# 289 16.8 kmpl
# 290 18.9 kmpl
# 291 18.9 kmpl
# 292 16.95 kmpl
# 293 20.4 kmpl
# 294 16.95 kmpl
# 295 18.6 kmpl
# 296 18.6 kmpl
# 297 15.96 kmpl
# 298 17.1 kmpl
# 299 17.19 kmpl
# 300 21.01 kmpl
# 301 17.0 kmpl
# 302 19.7 kmpl
# 303 26.59 kmpl
# 304 19.1 kmpl
# 305 24.0 kmpl
# 306 nan
# 307 19.1 kmpl
# 308 18.6 kmpl
# 309 20.3 kmpl
# 310 16.1 kmpl
# 311 25.6 kmpl
# 312 25.6 kmpl
# 313 16.02 kmpl
# 314 19.01 kmpl
# 315 17.4 kmpl
# 316 nan
# 317 25.17 kmpl
# 318 12.99 kmpl
# 319 20.51 kmpl
# 320 21.38 kmpl
# 321 23.84 kmpl
# 322 24.0 kmpl
# 323 21.4 kmpl
# 324 16.1 kmpl
# 325 17.4 kmpl
# 326 20.4 kmpl
# 327 17.0 kmpl
# 328 17.3 kmpl
# 329 23.1 kmpl
# 330 12.8 kmpl
# 331 21.1 kmpl
# 332 23.08 kmpl
# 333 17.3 kmpl
# 334 17.1 kmpl
# 335 18.2 kmpl
# 336 nan
# 337 19.7 kmpl
# 338 19.3 kmpl
# 339 19.0 kmpl
# 340 20.77 kmpl
# 341 17.8 kmpl
# 342 23.08 kmpl
# 343 18.9 kmpl
# 344 20.0 kmpl
# 345 17.0 kmpl
# 346 17.01 kmpl
# 347 22.0 kmpl
# 348 20.63 kmpl
# 349 18.9 kmpl
# 350 14.24 kmpl
# 351 20.71 kmpl
# 352 18.5 kmpl
# 353 17.0 kmpl
# 354 16.95 kmpl
# 355 23.59 kmpl
# 356 20.36 kmpl
# 357 20.45 kmpl
# 358 15.1 kmpl
# 359 12.8 kmpl
# 360 15.64 kmpl
# 361 14.5 kmpl
# 362 14.84 kmpl
# 363 25.4 kmpl
# 364 23.08 kmpl
# 365 18.9 kmpl
# 366 26.59 kmpl
# 367 20.36 kmpl
# 368 25.17 kmpl
# 369 16.34 kmpl
# 370 13.6 kmpl
# 371 22.37 kmpl
# 372 19.33 kmpl
# 373 14.1 kmpl
# 374 18.0 kmpl
# 375 19.16 kmpl
# 376 21.79 kmpl
# 377 27.39 kmpl
# 378 18.2 kmpl
# 379 12.99 kmpl
# 380 22.0 kmpl
# 381 16.78 kmpl
# 382 22.0 kmpl
# 383 24.0 kmpl
# 384 16.78 kmpl
# 385 16.78 kmpl
# 386 19.0 kmpl
# 387 14.3 kmpl
# 388 16.8 kmpl
# 389 20.36 kmpl
# 390 nan
# 391 11.1 kmpl
# 392 26.59 kmpl
# 393 22.32 kmpl
# 394 12.8 kmpl
# 395 21.5 kmpl
# 396 13.9 kmpl
# 397 16.8 kmpl
# 398 22.74 kmpl
# 399 18.0 kmpl
# 400 28.4 kmpl
# 401 17.0 kmpl
# 402 20.88 km/kg
# 403 23.95 kmpl
# 404 16.0 kmpl
# 405 20.92 kmpl
# 406 21.1 kmpl
# 407 23.84 kmpl
# 408 15.1 kmpl
# 409 13.6 kmpl
# 410 22.37 kmpl
# 411 19.33 kmpl
# 412 14.1 kmpl
# 413 18.0 kmpl
# 414 19.16 kmpl
# 415 21.79 kmpl
# 416 27.39 kmpl
# 417 18.2 kmpl
# 418 12.99 kmpl
# 419 22.0 kmpl
# 420 16.78 kmpl
# 421 22.0 kmpl
# 422 24.0 kmpl
# 423 16.78 kmpl
# 424 16.78 kmpl
# 425 19.0 kmpl
# 426 14.3 kmpl
# 427 16.8 kmpl
# 428 23.8 kmpl
# 429 21.38 kmpl
# 430 19.7 kmpl
# 431 24.4 kmpl
# 432 12.99 kmpl
# 433 23.59 kmpl
# 434 28.4 kmpl
# 435 12.8 kmpl
# 436 23.08 kmpl
# 437 16.1 kmpl
# 438 23.4 kmpl
# 439 20.14 kmpl
# 440 21.0 kmpl
# 441 16.1 kmpl
# 442 25.2 kmpl
# 443 19.1 kmpl
# 444 16.1 kmpl
# 445 23.1 kmpl
# 446 20.0 kmpl
# 447 13.93 kmpl
# 448 18.16 kmpl
# 449 23.1 kmpl
# 450 15.29 kmpl
# 451 21.21 kmpl
# 452 17.6 kmpl
# 453 23.0 kmpl
# 454 21.19 kmpl
# 455 22.54 kmpl
# 456 23.8 kmpl
# 457 15.96 kmpl
# 458 20.45 kmpl
# 459 20.4 kmpl
# 460 22.5 kmpl
# 461 12.99 kmpl
# 462 18.6 kmpl
# 463 12.99 kmpl
# 464 27.39 kmpl
# 465 19.6 kmpl
# 466 18.2 kmpl
# 467 23.65 kmpl
# 468 12.55 kmpl
# 469 26.59 kmpl
# 470 12.55 kmpl
# 471 11.5 kmpl
# 472 17.0 kmpl
# 473 19.49 kmpl
# 474 16.2 kmpl
# 475 25.32 kmpl
# 476 16.02 kmpl
# 477 23.5 kmpl
# 478 16.6 kmpl
# 479 19.81 kmpl
# 480 19.0 kmpl
# 481 18.9 kmpl
# 482 23.9 kmpl
# 483 24.52 kmpl
# 484 25.2 kmpl
# 485 17.01 kmpl
# 486 25.2 kmpl
# 487 25.32 kmpl
# 488 20.8 kmpl
# 489 20.14 kmpl
# 490 18.5 kmpl
# 491 22.74 kmpl
# 492 27.62 kmpl
# 493 17.5 kmpl
# 494 20.54 kmpl
# 495 18.6 kmpl
# 496 23.59 kmpl
# 497 18.9 kmpl
# 498 28.4 kmpl
# 499 12.9 kmpl
# 500 17.5 kmpl
# 501 24.7 kmpl
# 502 22.74 kmpl
# 503 25.44 kmpl
# 504 23.84 kmpl
# 505 25.44 kmpl
# 506 13.93 kmpl
# 507 15.6 kmpl
# 508 17.88 kmpl
# 509 26.59 kmpl
# 510 28.4 kmpl
# 511 22.7 kmpl
# 512 20.92 kmpl
# 513 19.3 kmpl
# 514 17.2 kmpl
# 515 13.6 kmpl
# 516 nan
# 517 18.6 kmpl
# 518 21.1 kmpl
# 519 15.37 kmpl
# 520 17.5 kmpl
# 521 19.1 kmpl
# 522 18.6 kmpl
# 523 23.84 kmpl
# 524 18.2 kmpl
# 525 19.7 kmpl
# 526 17.1 kmpl
# 527 17.4 kmpl
# 528 20.54 kmpl
# 529 20.92 kmpl
# 530 18.6 kmpl
# 531 15.42 kmpl
# 532 16.02 kmpl
# 533 18.5 kmpl
# 534 21.1 kmpl
# 535 nan
# 536 15.3 kmpl
# 537 19.7 kmpl
# 538 18.2 kmpl
# 539 nan
# 540 17.57 kmpl
# 541 19.68 kmpl
# 542 19.7 kmpl
# 543 12.99 kmpl
# 544 13.6 kmpl
# 545 22.74 kmpl
# 546 20.51 kmpl
# 547 19.3 kmpl
# 548 14.1 kmpl
# 549 24.3 kmpl
# 550 11.36 kmpl
# 551 19.67 kmpl
# 552 24.3 kmpl
# 553 18.6 kmpl
# 554 18.9 kmpl
# 555 18.7 kmpl
# 556 15.4 kmpl
# 557 17.7 kmpl
# 558 19.34 kmpl
# 559 18.16 kmpl
# 560 21.1 kmpl
# 561 22.7 kmpl
# 562 19.0 kmpl
# 563 20.3 kmpl
# 564 23.0 kmpl
# 565 22.71 kmpl
# 566 18.9 kmpl
# 567 23.65 kmpl
# 568 23.0 kmpl
# 569 17.1 kmpl
# 570 20.77 kmpl
# 571 18.8 kmpl
# 572 18.9 kmpl
# 573 21.14 kmpl
# 574 22.32 kmpl
# 575 nan
# 576 nan
# 577 15.4 kmpl
# 578 19.01 kmpl
# 579 15.1 kmpl
# 580 24.7 kmpl
# 581 20.0 kmpl
# 582 20.36 kmpl
# 583 21.21 kmpl
# 584 15.96 kmpl
# 585 20.51 kmpl
# 586 21.1 kmpl
# 587 12.8 kmpl
# 588 13.5 kmpl
# 589 25.44 kmpl
# 590 21.66 kmpl
# 591 17.6 kmpl
# 592 21.1 kmpl
# 593 25.17 kmpl
# 594 19.0 kmpl
# 595 12.99 kmpl
# 596 18.2 kmpl
# 597 22.32 kmpl
# 598 25.8 kmpl
# 599 22.0 kmpl
# 600 14.24 kmpl
# 601 15.8 kmpl
# 602 18.9 kmpl
# 603 13.7 kmpl
# 604 12.2 kmpl
# 605 18.8 kmpl
# 606 19.81 kmpl
# 607 19.09 kmpl
# 608 23.01 kmpl
# 609 13.6 kmpl
# 610 18.49 kmpl
# 611 26.59 kmpl
# 612 22.74 kmpl
# 613 24.52 kmpl
# 614 24.0 kmpl
# 615 20.0 kmpl
# 616 16.8 kmpl
# 617 18.9 kmpl
# 618 19.81 kmpl
# 619 17.57 kmpl
# 620 23.95 kmpl
# 621 24.52 kmpl
# 622 14.1 kmpl
# 623 23.95 kmpl
# 624 24.0 kmpl
# 625 25.17 kmpl
# 626 22.9 kmpl
# 627 15.96 kmpl
# 628 9.0 kmpl
# 629 23.95 kmpl
# 630 23.4 kmpl
# 631 21.1 kmpl
# 632 15.4 kmpl
# 633 23.95 kmpl
# 634 24.0 kmpl
# 635 22.77 kmpl
# 636 20.51 kmpl
# 637 15.96 kmpl
# 638 23.0 kmpl
# 639 22.95 kmpl
# 640 16.55 kmpl
# 641 14.0 kmpl
# 642 14.0 kmpl
# 643 18.9 kmpl
# 644 0.0 kmpl
# 645 18.9 kmpl
# 646 13.6 kmpl
# 647 22.37 kmpl
# 648 19.33 kmpl
# 649 14.1 kmpl
# 650 18.0 kmpl
# 651 19.16 kmpl
# 652 21.79 kmpl
# 653 27.39 kmpl
# 654 18.2 kmpl
# 655 12.99 kmpl
# 656 22.0 kmpl
# 657 16.78 kmpl
# 658 22.0 kmpl
# 659 24.0 kmpl
# 660 16.78 kmpl
# 661 16.78 kmpl
# 662 19.0 kmpl
# 663 14.3 kmpl
# 664 16.8 kmpl
# 665 18.49 kmpl
# 666 19.0 kmpl
# 667 20.36 kmpl
# 668 16.55 kmpl
# 669 20.3 kmpl
# 670 19.7 kmpl
# 671 17.1 kmpl
# 672 25.1 kmpl
# 673 18.49 kmpl
# 674 19.0 kmpl
# 675 19.1 kmpl
# 676 18.15 kmpl
# 677 19.0 kmpl
# 678 21.21 kmpl
# 679 23.0 kmpl
# 680 17.8 kmpl
# 681 13.0 kmpl
# 682 11.5 kmpl
# 683 18.15 kmpl
# 684 20.54 kmpl
# 685 18.16 kmpl
# 686 15.96 kmpl
# 687 17.92 kmpl
# 688 nan
# 689 17.92 kmpl
# 690 22.71 kmpl
# 691 17.92 kmpl
# 692 20.51 kmpl
# 693 19.81 kmpl
# 694 14.0 kmpl
# 695 18.9 kmpl
# 696 19.09 kmpl
# 697 13.6 kmpl
# 698 28.4 kmpl
# 699 17.8 kmpl
# 700 23.01 kmpl
# 701 14.0 kmpl
# 702 18.9 kmpl
# 703 13.6 kmpl
# 704 18.49 kmpl
# 705 21.1 kmpl
# 706 19.0 kmpl
# 707 23.1 kmpl
# 708 21.1 kmpl
# 709 26.0 kmpl
# 710 13.6 kmpl
# 711 13.58 kmpl
# 712 22.54 kmpl
# 713 18.6 kmpl
# 714 18.49 kmpl
# 715 13.5 kmpl
# 716 10.1 kmpl
# 717 20.63 kmpl
# 718 18.15 kmpl
# 719 21.9 kmpl
# 720 23.1 kmpl
# 721 13.2 kmpl
# 722 15.96 kmpl
# 723 19.09 kmpl
# 724 15.96 kmpl
# 725 nan
# 726 13.6 kmpl
# 727 15.96 kmpl
# 728 16.95 kmpl
# 729 21.02 kmpl
# 730 24.4 kmpl
# 731 20.14 kmpl
# 732 19.0 kmpl
# 733 20.5 kmpl
# 734 15.96 kmpl
# 735 13.6 kmpl
# 736 12.99 kmpl
# 737 18.9 kmpl
# 738 23.01 kmpl
# 739 20.14 kmpl
# 740 18.6 kmpl
# 741 20.4 kmpl
# 742 16.0 kmpl
# 743 nan
# 744 nan
# 745 16.8 kmpl
# 746 18.9 kmpl
# 747 nan
# 748 27.28 kmpl
# 749 23.95 kmpl
# 750 15.37 kmpl
# 751 12.05 kmpl
# 752 12.8 kmpl
# 753 25.0 kmpl
# 754 18.16 kmpl
# 755 10.5 kmpl
# 756 nan
# 757 21.1 kmpl
# 758 21.1 kmpl
# 759 19.7 kmpl
# 760 17.88 kmpl
# 761 24.3 kmpl
# 762 22.07 kmpl
# 763 18.9 kmpl
# 764 13.0 kmpl
# 765 15.96 kmpl
# 766 20.4 kmpl
# 767 24.0 kmpl
# 768 19.3 kmpl
# 769 23.0 kmpl
# 770 14.0 kmpl
# 771 17.8 kmpl
# 772 15.4 kmpl
# 773 23.95 kmpl
# 774 nan
# 775 13.5 kmpl
# 776 nan
# 777 22.3 kmpl
# 778 12.8 kmpl
# 779 18.9 kmpl
# 780 19.0 kmpl
# 781 15.1 kmpl
# 782 15.26 kmpl
# 783 13.6 kmpl
# 784 10.5 kmpl
# 785 0.0 kmpl
# 786 22.7 kmpl
# 787 13.6 kmpl
# 788 19.1 kmpl
# 789 19.09 kmpl
# 790 19.0 kmpl
# 791 16.1 kmpl
# 792 12.9 kmpl
# 793 15.1 kmpl
# 794 19.7 kmpl
# 795 12.2 kmpl
# 796 22.9 kmpl
# 797 20.62 kmpl
# 798 19.3 kmpl
# 799 23.01 kmpl
# 800 18.2 kmpl
# 801 20.51 kmpl
# 802 20.4 kmpl
# 803 21.1 kmpl
# 804 19.01 kmpl
# 805 17.7 kmpl
# 806 20.3 kmpl
# 807 19.3 kmpl
# 808 16.1 kmpl
# 809 27.4 kmpl
# 810 16.02 kmpl
# 811 18.8 kmpl
# 812 16.02 kmpl
# 813 18.6 kmpl
# 814 16.8 kmpl
# 815 18.8 kmpl
# 816 13.6 kmpl
# 817 19.7 kmpl
# 818 19.7 kmpl
# 819 25.8 kmpl
# 820 12.99 kmpl
# 821 21.1 kmpl
# 822 20.51 kmpl
# 823 21.4 kmpl
# 824 18.5 kmpl
# 825 23.2 kmpl
# 826 19.67 kmpl
# 827 20.85 kmpl
# 828 23.9 kmpl
# 829 16.0 kmpl
# 830 18.6 kmpl
# 831 17.8 kmpl
# 832 22.74 kmpl
# 833 22.74 kmpl
# 834 22.77 kmpl
# 835 20.8 kmpl
# 836 20.51 kmpl
# 837 20.51 kmpl
# 838 14.07 kmpl
# 839 19.0 kmpl
# 840 14.4 kmpl
# 841 18.5 kmpl
# 842 17.0 kmpl
# 843 19.81 kmpl
# 844 18.9 kmpl
# 845 16.6 kmpl
# 846 18.15 kmpl
# 847 19.81 kmpl
# 848 28.4 kmpl
# 849 18.4 kmpl
# 850 19.7 kmpl
# 851 12.05 kmpl
# 852 16.8 kmpl
# 853 20.3 kmpl
# 854 28.4 kmpl
# 855 20.77 kmpl
# 856 12.8 kmpl
# 857 23.01 kmpl
# 858 18.2 kmpl
# 859 16.8 kmpl
# 860 18.6 kmpl
# 861 25.17 kmpl
# 862 nan
# 863 22.32 kmpl
# 864 24.7 kmpl
# 865 20.77 kmpl
# 866 30.46 km/kg
# 867 25.17 kmpl
# 868 21.1 kmpl
# 869 26.59 kmpl
# 870 26.2 km/kg
# 871 21.43 kmpl
# 872 18.5 kmpl
# 873 18.6 kmpl
# 874 21.12 kmpl
# 875 14.02 kmpl
# 876 17.0 kmpl
# 877 14.02 kmpl
# 878 19.09 kmpl
# 879 17.8 kmpl
# 880 23.1 kmpl
# 881 20.0 kmpl
# 882 25.44 kmpl
# 883 11.0 kmpl
# 884 25.17 kmpl
# 885 18.2 kmpl
# 886 13.6 kmpl
# 887 19.09 kmpl
# 888 13.2 kmpl
# 889 17.7 kmpl
# 890 15.96 kmpl
# 891 15.4 kmpl
# 892 20.6 kmpl
# 893 20.0 kmpl
# 894 13.6 kmpl
# 895 19.09 kmpl
# 896 25.5 kmpl
# 897 17.7 kmpl
# 898 21.9 kmpl
# 899 24.3 kmpl
# 900 18.6 kmpl
# 901 16.1 kmpl
# 902 20.0 kmpl
# 903 12.8 kmpl
# 904 11.5 kmpl
# 905 17.0 kmpl
# 906 16.55 kmpl
# 907 23.59 kmpl
# 908 18.9 kmpl
# 909 18.5 kmpl
# 910 21.1 kmpl
# 911 22.95 kmpl
# 912 22.3 kmpl
# 913 21.1 kmpl
# 914 24.0 kmpl
# 915 15.1 kmpl
# 916 20.62 kmpl
# 917 19.3 kmpl
# 918 18.49 kmpl
# 919 21.9 kmpl
# 920 22.05 kmpl
# 921 25.17 kmpl
# 922 19.01 kmpl
# 923 21.19 kmpl
# 924 18.49 kmpl
# 925 15.96 kmpl
# 926 12.99 kmpl
# 927 24.7 kmpl
# 928 25.1 kmpl
# 929 20.3 kmpl
# 930 20.77 kmpl
# 931 25.2 kmpl
# 932 20.2 kmpl
# 933 25.44 kmpl
# 934 21.19 kmpl
# 935 21.5 kmpl
# 936 18.9 kmpl
# 937 25.0 kmpl
# 938 16.1 kmpl
# 939 22.32 kmpl
# 2514 18.9 kmpl
# 2515 20.77 kmpl
# 2516 26.59 kmpl
# 2517 23.01 kmpl
# 2518 26.2 km/kg
# 2519 26.59 kmpl
# 2520 26.59 kmpl
# 2521 18.9 kmpl
# 2522 20.46 kmpl
# 2523 21.1 kmpl
# 2524 18.9 kmpl
# 2525 21.94 km/kg
# 2526 23.59 kmpl
# 2527 26.6 km/kg
# 2528 18.5 kmpl
# 2529 20.3 kmpl
# 2530 15.37 kmpl
# 2531 23.59 kmpl
# 2532 21.2 kmpl
# 2533 20.4 kmpl
# 2534 17.4 kmpl
# 2535 25.8 kmpl
# 2536 13.4 kmpl
# 2537 12.55 kmpl
# 2538 20.3 kmpl
# 2539 16.0 kmpl
# 2540 18.6 kmpl
# 2541 15.4 kmpl
# 2542 22.9 kmpl
# 2543 16.52 kmpl
# 2544 23.2 kmpl
# 2545 21.43 kmpl
# 2546 20.92 kmpl
# 2547 19.7 kmpl
# 2548 25.44 kmpl
# 2549 nan
# 2550 nan
# 2551 nan
# 2552 20.45 kmpl
# 2553 18.9 kmpl
# 2554 23.59 kmpl
# 2555 26.0 kmpl
# 2556 15.1 kmpl
# 2557 26.0 kmpl
# 2558 16.0 kmpl
# 2559 13.58 kmpl
# 2560 15.5 kmpl
# 2561 13.49 kmpl
# 2562 18.15 kmpl
# 2563 17.0 kmpl
# 2564 22.32 kmpl
# 2565 18.6 kmpl
# 2566 21.12 kmpl
# 2567 20.92 kmpl
# 2568 24.7 kmpl
# 2569 25.17 kmpl
# 2570 16.5 kmpl
# 2571 22.7 kmpl
# 2572 23.95 kmpl
# 2573 26.6 km/kg
# 2574 22.0 kmpl
# 2575 28.4 kmpl
# 2576 23.95 kmpl
# 2577 25.44 kmpl
# 2578 17.0 kmpl
# 2579 26.2 km/kg
# 2580 25.2 kmpl
# 2581 15.1 kmpl
# 2582 16.5 kmpl
# 2583 19.1 kmpl
# 2584 24.8 kmpl
# 2585 12.99 kmpl
# 2586 12.8 kmpl
# 2587 22.7 kmpl
# 2588 26.2 km/kg
# 2589 24.3 kmpl
# 2590 21.64 kmpl
# 2591 12.9 kmpl
# 2592 12.8 kmpl
# 2593 16.55 kmpl
# 2594 24.0 kmpl
# 2595 18.0 kmpl
# 2596 20.63 kmpl
# 2597 18.2 kmpl
# 2598 18.9 kmpl
# 2599 22.1 kmpl
# 2600 20.14 kmpl
# 2601 25.6 kmpl
# 2602 20.3 kmpl
# 2603 20.3 kmpl
# 2604 20.36 kmpl
# 2605 24.0 kmpl
# 2606 22.9 kmpl
# 2607 20.54 kmpl
# 2608 22.32 kmpl
# 2609 18.9 kmpl
# 2610 22.54 kmpl
# 2611 24.8 kmpl
# 2612 17.8 kmpl
# 2613 11.88 km/kg
# 2614 22.32 kmpl
# 2615 18.0 kmpl
# 2616 17.88 kmpl
# 2617 23.59 kmpl
# 2618 26.2 km/kg
# 2619 15.1 kmpl
# 2620 18.9 kmpl
# 2621 14.6 kmpl
# 2622 10.75 kmpl
# 2623 22.74 kmpl
# 2624 21.4 kmpl
# 2625 23.95 kmpl
# 2737 18.9 kmpl
# 2738 19.4 kmpl
# 2739 25.8 kmpl
# 2740 26.3 km/kg
# 2741 23.0 kmpl
# 2742 15.0 kmpl
# 2743 19.44 kmpl
# 2744 25.4 kmpl
# 2745 26.59 kmpl
# 2746 19.3 kmpl
# 2747 24.52 kmpl
# 2748 22.9 kmpl
# 2749 23.26 kmpl
# 2750 18.6 kmpl
# 2751 27.4 kmpl
# 2752 19.81 kmpl
# 2753 17.92 kmpl
# 2754 17.92 kmpl
# 2755 24.3 kmpl
# 2756 27.39 kmpl
# 2757 23.95 kmpl
# 2758 23.7 km/kg
# 2759 25.1 kmpl
# 2760 20.77 kmpl
# 2761 16.1 kmpl
# 2762 22.74 kmpl
# 2763 21.1 kmpl
# 2764 19.81 kmpl
# 2765 17.01 kmpl
# 2766 22.74 kmpl
# 2767 26.6 km/kg
# 2768 18.9 kmpl
# 2769 14.0 kmpl
# 2770 26.0 kmpl
# 2771 15.96 kmpl
# 2772 14.09 kmpl
# 2773 23.95 kmpl
# 2774 19.09 kmpl
# 2775 21.1 kmpl
# 2776 19.7 kmpl
# 2777 22.32 kmpl
# 2778 13.93 kmpl
# 2779 23.84 kmpl
# 2780 15.96 kmpl
# 2781 14.02 kmpl
# 2782 12.2 kmpl
# 2783 18.9 kmpl
# 2784 16.1 kmpl
# 2785 19.7 kmpl
# 2786 19.1 kmpl
# 2787 20.0 kmpl
# 2788 18.6 kmpl
# 2789 17.0 kmpl
# 2790 24.5 kmpl
# 2791 25.2 kmpl
# 2792 18.5 kmpl
# 2793 16.6 kmpl
# 2794 14.0 kmpl
# 2795 17.1 kmpl
# 2796 22.54 kmpl
# 2797 18.9 kmpl
# 2798 20.4 kmpl
# 2799 25.17 kmpl
# 2800 28.09 kmpl
# 2801 17.5 kmpl
# 2802 19.87 kmpl
# 2803 24.52 kmpl
# 2804 17.7 kmpl
# 2805 12.8 kmpl
# 2806 19.7 kmpl
# 2807 16.84 kmpl
# 2808 18.6 kmpl
# 2809 25.17 kmpl
# 2810 16.8 kmpl
# 2811 19.1 kmpl
# 2812 25.8 kmpl
# 2813 20.89 kmpl
# 2814 16.5 kmpl
# 2815 12.05 kmpl
# 2816 26.59 kmpl
# 2817 19.72 kmpl
# 2818 16.1 kmpl
# 2819 25.83 kmpl
# 2820 21.1 kmpl
# 2821 16.1 kmpl
# 2822 25.47 kmpl
# 2823 12.55 kmpl
# 2824 24.3 kmpl
# 2825 28.09 kmpl
# 2826 14.74 kmpl
# 2827 17.05 kmpl
# 2828 15.73 kmpl
# 2829 22.48 kmpl
# 2830 22.1 kmpl
# 2831 24.7 kmpl
# 2832 16.0 kmpl
# 2833 15.4 kmpl
# 2834 22.27 kmpl
# 2835 25.47 kmpl
# 2836 21.63 kmpl
# 2837 19.09 kmpl
# 2838 12.99 kmpl
# 2839 13.1 kmpl
# 2840 9.0 kmpl
# 2841 17.01 kmpl
# 2842 22.0 kmpl
# 2843 20.46 kmpl
# 2844 23.4 kmpl
# 2845 15.4 kmpl
# 2846 15.96 kmpl
# 2847 25.4 kmpl
# 2960 17.21 kmpl
# 2961 18.06 kmpl
# 2962 20.86 kmpl
# 2963 21.21 kmpl
# 2964 14.84 kmpl
# 2965 15.3 kmpl
# 2966 21.21 kmpl
# 2967 20.85 kmpl
# 2968 23.01 kmpl
# 2969 18.16 kmpl
# 2970 15.1 kmpl
# 2971 19.1 kmpl
# 2972 19.7 kmpl
# 2973 16.47 kmpl
# 2974 17.0 kmpl
# 2975 11.5 kmpl
# 2976 18.6 kmpl
# 2977 12.99 kmpl
# 2978 16.5 kmpl
# 2979 19.67 kmpl
# 2980 20.77 kmpl
# 2981 12.8 kmpl
# 2982 25.17 kmpl
# 2983 15.4 kmpl
# 2984 22.95 kmpl
# 2985 15.04 kmpl
# 2986 15.6 kmpl
# 2987 21.21 kmpl
# 2988 21.1 kmpl
# 2989 27.3 kmpl
# 2990 23.84 kmpl
# 2991 23.84 kmpl
# 2992 19.49 kmpl
# 2993 15.96 kmpl
# 2994 17.5 kmpl
# 2995 nan
# 2996 20.3 kmpl
# 2997 21.1 kmpl
# 2998 17.5 kmpl
# 2999 13.6 kmpl
# 3000 23.4 kmpl
# 3001 23.0 kmpl
# 3002 25.17 kmpl
# 3003 19.7 kmpl
# 3004 21.1 kmpl
# 3005 18.9 kmpl
# 3006 23.4 kmpl
# 3007 22.54 kmpl
# 3008 19.1 kmpl
# 3009 19.4 kmpl
# 3010 13.45 km/kg
# 3011 19.7 kmpl
# 3012 18.6 kmpl
# 3013 18.6 kmpl
# 3014 18.9 kmpl
# 3015 20.3 kmpl
# 3016 17.0 kmpl
# 3017 25.44 kmpl
# 3018 19.7 kmpl
# 3019 19.7 kmpl
# 3020 16.8 kmpl
# 3021 18.2 kmpl
# 3022 19.7 kmpl
# 3023 28.4 kmpl
# 3024 15.96 kmpl
# 3025 18.9 kmpl
# 3026 17.7 kmpl
# 3027 26.59 kmpl
# 3028 18.6 kmpl
# 3029 18.6 kmpl
# 3030 20.36 kmpl
# 3031 21.1 kmpl
# 3032 18.9 kmpl
# 3033 20.36 kmpl
# 3034 17.01 kmpl
# 3035 20.63 kmpl
# 3036 28.4 kmpl
# 3037 22.5 kmpl
# 3038 21.66 kmpl
# 3039 15.96 kmpl
# 3040 15.96 kmpl
# 3041 15.96 kmpl
# 3042 19.2 km/kg
# 3043 13.93 kmpl
# 3044 22.9 kmpl
# 3045 23.2 kmpl
# 3046 16.1 kmpl
# 3047 12.8 kmpl
# 3048 15.96 kmpl
# 3049 20.0 kmpl
# 3050 26.2 km/kg
# 3051 22.9 kmpl
# 3052 24.3 kmpl
# 3053 21.21 kmpl
# 3054 17.5 kmpl
# 3055 16.8 kmpl
# 3056 22.0 kmpl
# 3057 15.96 kmpl
# 3058 19.67 kmpl
# 3059 15.0 kmpl
# 3060 17.92 kmpl
# 3061 13.93 kmpl
# 3062 nan
# 3063 19.4 kmpl
# 3064 18.9 kmpl
# 3065 19.33 kmpl
# 3066 16.0 kmpl
# 3067 10.9 kmpl
# 3068 28.4 kmpl
# 3069 20.51 kmpl
# 3070 18.6 kmpl
# 3071 24.3 kmpl
# 3072 18.9 kmpl
# 3073 18.0 kmpl
# 3074 23.0 kmpl
# 3075 21.1 kmpl
# 3076 22.0 kmpl
# 3077 23.1 kmpl
# 3078 13.6 kmpl
# 3079 22.37 kmpl
# 3080 19.33 kmpl
# 3081 14.1 kmpl
# 3082 18.0 kmpl
# 3083 19.16 kmpl
# 3084 21.79 kmpl
# 3085 27.39 kmpl
# 3086 18.2 kmpl
# 3087 12.99 kmpl
# 3088 22.0 kmpl
# 3089 16.78 kmpl
# 3090 22.0 kmpl
# 3091 24.0 kmpl
# 3092 16.78 kmpl
# 3093 16.78 kmpl
# 3094 19.0 kmpl
# 3095 14.3 kmpl
# 3096 16.8 kmpl
# 3097 nan
# 3098 23.0 kmpl
# 3099 21.79 kmpl
# 3100 27.39 kmpl
# 3101 22.0 kmpl
# 3102 16.78 kmpl
# 3103 22.0 kmpl
# 3104 24.0 kmpl
# 3105 18.5 kmpl
# 3106 20.36 kmpl
# 3107 11.74 kmpl
# 3108 16.47 kmpl
# 3109 18.9 kmpl
# 3110 18.25 kmpl
# 3111 11.36 kmpl
# 3112 15.8 kmpl
# 3113 18.6 kmpl
# 3114 19.67 kmpl
# 3115 28.4 kmpl
# 3116 19.67 kmpl
# 3117 20.52 kmpl
# 3118 22.95 kmpl
# 3119 17.8 kmpl
# 3120 12.05 kmpl
# 3121 20.45 kmpl
# 3122 22.07 kmpl
# 3123 21.1 kmpl
# 3124 18.5 kmpl
# 3125 19.7 kmpl
# 3126 15.3 kmpl
# 3127 18.1 kmpl
# 3128 19.7 kmpl
# 3129 28.09 kmpl
# 3130 19.34 kmpl
# 3131 13.0 kmpl
# 3132 18.15 kmpl
# 3133 19.1 kmpl
# 3134 13.2 kmpl
# 3135 24.3 kmpl
# 3136 24.3 kmpl
# 3137 23.59 kmpl
# 3138 22.95 kmpl
# 3139 25.8 kmpl
# 3140 20.63 kmpl
# 3141 18.49 kmpl
# 3142 17.0 kmpl
# 3143 15.96 kmpl
# 3144 15.2 kmpl
# 3145 20.36 kmpl
# 3146 26.0 kmpl
# 3147 21.4 kmpl
# 3148 21.1 kmpl
# 3149 20.65 kmpl
# 3150 20.36 kmpl
# 3151 20.77 kmpl
# 3152 18.6 kmpl
# 3153 19.09 kmpl
# 3154 nan
# 3155 15.6 kmpl
# 3156 15.96 kmpl
# 3157 22.3 kmpl
# 3158 20.0 kmpl
# 3159 15.1 kmpl
# 3160 21.19 kmpl
# 3161 19.62 kmpl
# 3162 25.1 kmpl
# 3163 26.59 kmpl
# 3164 21.0 kmpl
# 3165 21.7 kmpl
# 3166 27.4 kmpl
# 3167 15.0 kmpl
# 3168 12.8 kmpl
# 3169 15.3 kmpl
# 3170 21.0 kmpl
# 3171 13.93 kmpl
# 3172 15.4 kmpl
# 3173 nan
# 3174 18.9 kmpl
# 3175 19.1 kmpl
# 3176 19.67 kmpl
# 3177 21.38 kmpl
# 3178 21.7 kmpl
# 3179 16.1 kmpl
# 3180 17.57 kmpl
# 3181 17.57 kmpl
# 3182 16.0 kmpl
# 3183 19.4 kmpl
# 3184 16.0 kmpl
# 3185 18.9 kmpl
# 3186 24.0 kmpl
# 3187 21.1 kmpl
# 3188 17.8 kmpl
# 3189 25.0 kmpl
# 3190 20.4 kmpl
# 3191 20.4 kmpl
# 3192 28.09 kmpl
# 3193 20.37 kmpl
# 3194 nan
# 3195 17.8 kmpl
# 3196 21.19 kmpl
# 3197 25.0 kmpl
# 3198 22.95 kmpl
# 3199 25.44 kmpl
# 3200 26.6 km/kg
# 3201 24.52 kmpl
# 3202 20.0 kmpl
# 3203 12.99 kmpl
# 3204 20.63 kmpl
# 3205 19.81 kmpl
# 3206 18.6 kmpl
# 3207 20.36 kmpl
# 3208 20.86 kmpl
# 3209 17.6 kmpl
# 3210 18.0 kmpl
# 3211 18.8 kmpl
# 3212 12.99 kmpl
# 3213 18.49 kmpl
# 3214 10.91 kmpl
# 3215 24.0 kmpl
# 3216 17.8 km/kg
# 3217 17.01 kmpl
# 3218 22.05 kmpl
# 3219 18.6 kmpl
# 3220 22.54 kmpl
# 3221 24.3 kmpl
# 3222 21.1 kmpl
# 3223 21.21 kmpl
# ...
# 7079 21.8 kmpl
# 7080 16.55 kmpl
# 7081 18.1 kmpl
# 7082 13.6 kmpl
# 7083 16.78 kmpl
# 7084 13.6 kmpl
# 7085 20.14 kmpl
# 7086 nan
# 7087 22.74 kmpl
# 7088 22.9 kmpl
# 7089 22.32 kmpl
# 7090 21.1 kmpl
# 7091 20.85 kmpl
# 7092 24.52 kmpl
# 7093 24.7 kmpl
# 7094 22.1 kmpl
# 7095 15.64 kmpl
# 7096 23.0 kmpl
# 7097 18.49 kmpl
# 7098 15.96 kmpl
# 7099 13.24 kmpl
# 7100 27.28 kmpl
# 7101 13.2 km/kg
# 7102 12.8 kmpl
# 7103 16.02 kmpl
# 7104 17.92 kmpl
# 7105 20.92 kmpl
# 7106 15.96 kmpl
# 7107 24.3 kmpl
# 7108 23.0 kmpl
# 7109 22.9 kmpl
# 7110 23.4 kmpl
# 7111 23.4 kmpl
# 7112 14.4 km/kg
# 7113 21.1 kmpl
# 7114 17.5 kmpl
# 7115 12.0 kmpl
# 7116 23.59 kmpl
# 7117 13.58 kmpl
# 7118 15.3 kmpl
# 7119 19.34 kmpl
# 7120 18.9 kmpl
# 7121 19.7 kmpl
# 7122 24.7 kmpl
# 7123 21.7 kmpl
# 7124 19.87 kmpl
# 7125 13.93 kmpl
# 7126 18.49 kmpl
# 7127 nan
# 7128 18.9 kmpl
# 7129 17.1 kmpl
# 7130 15.96 kmpl
# 7131 15.96 kmpl
# 7132 15.26 kmpl
# 7133 15.1 kmpl
# 7134 14.7 kmpl
# 7135 21.4 kmpl
# 7136 16.47 kmpl
# 7137 19.1 kmpl
# 7138 24.7 kmpl
# 7139 17.4 kmpl
# 7140 19.49 kmpl
# 7141 18.6 kmpl
# 7142 18.6 kmpl
# 7143 17.5 kmpl
# 7144 22.5 kmpl
# 7145 23.84 kmpl
# 7146 25.8 kmpl
# 7147 18.16 kmpl
# 7148 13.1 kmpl
# 7149 18.15 kmpl
# 7150 13.58 kmpl
# 7151 21.1 kmpl
# 7152 13.58 kmpl
# 7153 25.83 kmpl
# 7154 18.7 kmpl
# 7155 17.3 kmpl
# 7156 20.51 kmpl
# 7157 20.51 kmpl
# 7158 18.6 kmpl
# 7159 25.17 kmpl
# 7160 18.6 kmpl
# 7161 15.0 kmpl
# 7162 17.6 kmpl
# 7163 17.6 kmpl
# 7164 23.03 kmpl
# 7165 21.19 kmpl
# 7166 26.6 km/kg
# 7167 17.8 kmpl
# 7168 17.8 kmpl
# 7169 23.01 kmpl
# 7170 23.4 kmpl
# 7171 17.0 kmpl
# 7172 17.2 kmpl
# 7173 18.6 kmpl
# 7174 13.68 kmpl
# 7175 18.3 kmpl
# 7176 17.6 kmpl
# 7177 26.0 kmpl
# 7178 13.7 kmpl
# 7179 nan
# 7180 25.8 kmpl
# 7181 23.0 kmpl
# 7182 19.02 kmpl
# 7183 16.0 kmpl
# 7184 22.07 kmpl
# 7185 21.21 kmpl
# 7186 18.49 kmpl
# 7187 18.2 kmpl
# 7188 19.81 kmpl
# 7189 14.8 kmpl
# 7190 12.99 kmpl
# 7191 17.43 kmpl
# 7192 20.51 kmpl
# 7193 21.1 kmpl
# 7194 21.1 kmpl
# 7195 26.0 kmpl
# 7196 17.92 kmpl
# 7197 19.7 kmpl
# 7198 23.0 kmpl
# 7199 21.1 kmpl
# 7200 25.32 kmpl
# 7201 19.3 kmpl
# 7202 18.6 kmpl
# 7203 25.2 kmpl
# 7204 18.9 kmpl
# 7205 17.7 kmpl
# 7206 18.9 kmpl
# 7207 21.1 kmpl
# 7208 nan
# 7209 18.9 kmpl
# 7210 17.0 kmpl
# 7211 20.8 kmpl
# 7212 11.5 kmpl
# 7213 16.52 kmpl
# 7214 22.32 kmpl
# 7215 17.88 kmpl
# 7216 22.32 kmpl
# 7217 22.5 kmpl
# 7218 16.1 kmpl
# 7219 22.07 kmpl
# 7220 21.21 kmpl
# 7221 26.59 kmpl
# 7222 25.1 kmpl
# 7223 17.7 kmpl
# 7224 12.8 kmpl
# 7225 24.7 kmpl
# 7226 23.95 kmpl
# 7227 16.2 kmpl
# 7228 20.51 kmpl
# 7229 19.0 kmpl
# 7230 28.4 kmpl
# 7231 15.1 kmpl
# 7232 17.2 kmpl
# 7233 21.4 kmpl
# 7234 20.89 kmpl
# 7235 20.51 kmpl
# 7236 24.3 kmpl
# 7237 24.0 kmpl
# 7238 23.4 kmpl
# 7239 18.06 kmpl
# 7240 21.1 kmpl
# 7241 22.07 kmpl
# 7242 25.32 kmpl
# 7243 19.3 kmpl
# 7244 18.12 kmpl
# 7245 13.45 km/kg
# 7246 15.37 kmpl
# 7247 16.55 kmpl
# 7248 19.1 kmpl
# 7249 25.32 kmpl
# 7250 17.92 kmpl
# 7251 20.51 kmpl
# 7252 23.95 kmpl
# 7253 25.44 kmpl
# 7254 20.65 kmpl
# 7255 18.9 kmpl
# 7256 22.3 kmpl
# 7257 16.5 kmpl
# 7258 19.68 kmpl
# 7259 13.6 kmpl
# 7260 19.68 kmpl
# 7261 20.0 kmpl
# 7262 17.45 kmpl
# 7263 23.95 kmpl
# 7264 26.21 kmpl
# 7265 20.51 kmpl
# 7266 23.57 kmpl
# 7267 18.49 kmpl
# 7268 25.17 kmpl
# 7269 23.95 kmpl
# 7270 16.1 kmpl
# 7271 20.92 kmpl
# 7272 nan
# 7273 20.4 kmpl
# 7274 13.6 kmpl
# 7275 nan
# 7276 21.66 kmpl
# 7277 12.99 kmpl
# 7278 15.1 kmpl
# 7279 21.49 kmpl
# 7280 22.54 kmpl
# 7281 18.0 kmpl
# 7282 28.4 kmpl
# 7283 22.54 kmpl
# 7284 27.3 kmpl
# 7285 28.4 kmpl
# 7286 20.0 kmpl
# 7287 17.3 kmpl
# 7288 14.62 kmpl
# 7289 25.44 kmpl
# 7290 28.4 kmpl
# 7291 17.01 kmpl
# 7292 22.15 kmpl
# 7293 23.65 kmpl
# 7294 21.14 kmpl
# 7295 14.3 kmpl
# 7296 18.7 kmpl
# 7297 23.9 kmpl
# 7298 28.4 kmpl
# 7299 28.4 kmpl
# 7300 26.83 km/kg
# 7301 19.3 kmpl
# 7302 nan
# 7303 15.1 kmpl
# 7304 24.04 kmpl
# 7305 19.5 kmpl
# 7306 18.6 kmpl
# 7307 20.77 kmpl
# 7308 26.83 km/kg
# 7309 20.77 kmpl
# 7310 17.8 kmpl
# 7311 24.0 kmpl
# 7312 24.0 kmpl
# 7313 17.2 kmpl
# 7314 13.2 kmpl
# 7315 17.19 kmpl
# 7316 14.09 kmpl
# 7317 21.1 kmpl
# 7318 13.58 kmpl
# 7319 18.49 kmpl
# 7320 20.54 kmpl
# 7321 19.2 kmpl
# 7322 24.3 kmpl
# 7323 20.4 kmpl
# 7324 15.73 kmpl
# 7325 26.8 kmpl
# 7326 19.62 kmpl
# 7327 18.2 kmpl
# 7328 24.5 kmpl
# 7329 27.39 kmpl
# 7330 22.15 kmpl
# 7331 11.36 kmpl
# 7332 20.7 kmpl
# 7333 21.04 kmpl
# 7334 17.4 kmpl
# 7335 11.45 kmpl
# 7336 12.08 kmpl
# 7337 0.0 kmpl
# 7338 20.3 kmpl
# 7339 23.1 kmpl
# 7340 17.9 kmpl
# 7341 17.0 kmpl
# 7342 19.67 kmpl
# 7343 16.78 kmpl
# 7344 25.8 kmpl
# 7345 14.95 kmpl
# 7346 19.3 kmpl
# 7347 21.9 kmpl
# 7348 21.9 kmpl
# 7349 24.3 kmpl
# 7350 12.99 kmpl
# 7351 28.4 kmpl
# 7352 22.0 kmpl
# 7353 19.3 kmpl
# 7354 16.8 kmpl
# 7355 17.8 kmpl
# 7356 20.54 kmpl
# 7357 25.2 kmpl
# 7358 nan
# 7359 18.7 kmpl
# 7360 25.2 kmpl
# 7361 nan
# 7362 26.0 kmpl
# 7363 17.8 kmpl
# 7364 28.4 kmpl
# 7365 23.1 kmpl
# 7366 21.4 kmpl
# 7367 25.6 kmpl
# 7368 17.3 kmpl
# 7369 28.4 kmpl
# 7370 13.68 kmpl
# 7371 21.01 kmpl
# 7372 27.62 kmpl
# 7373 nan
# 7374 18.25 kmpl
# 7375 15.1 kmpl
# 7376 19.56 kmpl
# 7377 21.01 kmpl
# 7378 17.8 kmpl
# 7379 17.68 kmpl
# 7380 21.1 kmpl
# 7381 16.0 kmpl
# 7382 23.1 kmpl
# 7383 18.9 kmpl
# 7384 22.74 kmpl
# 7385 17.43 kmpl
# 7386 20.4 kmpl
# 7387 20.0 kmpl
# 7388 20.92 kmpl
# 7389 19.7 kmpl
# 7390 28.4 kmpl
# 7391 28.4 kmpl
# 7392 19.09 kmpl
# 7393 23.59 kmpl
# 7394 14.95 kmpl
# 7395 21.9 kmpl
# 7396 13.6 kmpl
# 7397 21.02 kmpl
# 7398 16.0 kmpl
# 7399 17.8 kmpl
# 7400 20.4 kmpl
# 7401 16.6 kmpl
# 7402 15.74 kmpl
# 7403 14.81 kmpl
# 7404 13.5 kmpl
# 7405 21.1 kmpl
# 7406 25.8 kmpl
# 7407 15.0 kmpl
# 7408 23.0 kmpl
# 7409 20.5 kmpl
# 7410 21.21 kmpl
# 7411 13.68 kmpl
# 7412 16.1 kmpl
# 7413 20.4 kmpl
# 7414 18.6 kmpl
# 7415 20.3 kmpl
# 7416 20.92 kmpl
# 7417 20.0 kmpl
# 7418 21.1 kmpl
# 7419 23.0 kmpl
# 7420 23.57 kmpl
# 7421 23.03 kmpl
# 7422 nan
# 7423 23.2 kmpl
# 7424 17.5 kmpl
# 7425 17.0 kmpl
# 7426 15.1 kmpl
# 7427 13.58 kmpl
# 7428 23.59 kmpl
# 7429 21.21 kmpl
# 7430 17.36 kmpl
# 7431 25.1 kmpl
# 7432 23.84 kmpl
# 7433 nan
# 7434 25.83 kmpl
# 7435 12.99 kmpl
# 7436 15.1 kmpl
# 7437 nan
# 7438 23.2 kmpl
# 7439 10.5 kmpl
# 7440 18.5 kmpl
# 7441 21.9 kmpl
# 7442 15.4 kmpl
# 7443 23.9 kmpl
# 7444 22.27 kmpl
# 7445 21.1 kmpl
# 7446 24.52 kmpl
# 7447 19.7 kmpl
# 7448 18.6 kmpl
# 7449 17.0 kmpl
# 7450 22.0 kmpl
# 7451 20.0 kmpl
# 7452 17.0 kmpl
# 7453 20.3 kmpl
# 7454 nan
# 7455 25.83 kmpl
# 7456 20.3 kmpl
# 7457 23.03 kmpl
# 7458 22.5 kmpl
# 7459 16.78 kmpl
# 7460 19.09 kmpl
# 7461 25.0 kmpl
# 7462 12.05 kmpl
# 7463 18.88 kmpl
# 7464 19.01 kmpl
# 7465 25.83 kmpl
# 7466 13.6 kmpl
# 7467 19.81 kmpl
# 7468 19.7 kmpl
# 7469 17.0 kmpl
# 7470 25.5 kmpl
# 7471 14.8 kmpl
# 7472 15.64 kmpl
# 7473 nan
# 7474 28.09 kmpl
# 7475 17.0 kmpl
# 7476 25.17 kmpl
# 7477 17.1 kmpl
# 7478 22.32 kmpl
# 7479 17.4 kmpl
# 7480 20.77 kmpl
# 7481 17.01 kmpl
# 7482 22.54 kmpl
# 7483 16.4 kmpl
# 7484 24.04 kmpl
# 7485 13.1 kmpl
# 7486 21.04 kmpl
# 7487 14.0 kmpl
# 7488 21.19 kmpl
# 7489 16.8 kmpl
# 7490 18.16 kmpl
# 7491 24.5 kmpl
# 7492 20.3 kmpl
# 7493 16.1 kmpl
# 7494 21.04 kmpl
# 7495 17.1 kmpl
# 7496 15.3 kmpl
# 7497 20.4 kmpl
# 7498 12.8 kmpl
# 7499 19.33 kmpl
# 7500 28.4 kmpl
# 7501 23.4 kmpl
# 7502 25.17 kmpl
# 7503 19.01 kmpl
# 7504 20.0 kmpl
# 7505 25.32 kmpl
# 7506 11.3 kmpl
# 7507 21.66 kmpl
# 7508 17.68 kmpl
# 7509 18.1 kmpl
# 7510 16.8 kmpl
# 7511 18.1 kmpl
# 7512 16.47 kmpl
# 7513 16.96 kmpl
# 7514 10.1 kmpl
# 7515 22.9 kmpl
# 7516 11.2 kmpl
# 7517 19.67 kmpl
# 7518 24.4 kmpl
# 7519 20.45 kmpl
# 7520 17.8 kmpl
# 7521 16.52 kmpl
# 7522 11.36 kmpl
# 7523 25.6 kmpl
# 7524 14.8 kmpl
# 7525 20.54 kmpl
# 7526 17.8 kmpl
# 7527 17.7 kmpl
# 7528 nan
# 7529 26.0 kmpl
# 7530 26.0 kmpl
# 7531 17.88 kmpl
# 7532 18.7 kmpl
# 7533 24.7 kmpl
# 7534 23.4 kmpl
# 7535 18.9 kmpl
# 7536 23.1 kmpl
# 7537 15.6 kmpl
# 7538 nan
# 7539 14.0 kmpl
# 7540 19.81 kmpl
# 7541 18.6 kmpl
# 7542 24.3 kmpl
# 7543 33.44 km/kg
# 7544 23.95 kmpl
# 7545 17.0 kmpl
# 7546 20.63 kmpl
# 7547 17.92 kmpl
# 7548 13.93 kmpl
# 7549 16.1 kmpl
# 7550 20.4 kmpl
# 7551 16.6 kmpl
# 7552 15.74 kmpl
# 7553 14.81 kmpl
# 7554 13.5 kmpl
# 7555 21.1 kmpl
# 7556 25.8 kmpl
# 7557 15.0 kmpl
# 7558 23.0 kmpl
# 7559 20.5 kmpl
# 7560 21.21 kmpl
# 7561 13.68 kmpl
# 7562 16.1 kmpl
# 7563 20.4 kmpl
# 7564 18.6 kmpl
# 7565 20.3 kmpl
# 7566 20.92 kmpl
# 7567 20.0 kmpl
# 7568 21.1 kmpl
# 7569 23.0 kmpl
# 7570 21.4 kmpl
# 7571 21.03 kmpl
# 7572 17.57 kmpl
# 7573 15.0 kmpl
# 7574 22.32 kmpl
# 7575 15.1 kmpl
# 7576 20.3 kmpl
# 7577 18.9 kmpl
# 7578 28.4 kmpl
# 7579 27.3 kmpl
# 7580 23.08 kmpl
# 7581 nan
# 7582 nan
# 7583 16.8 kmpl
# 7584 14.4 kmpl
# 7585 17.0 kmpl
# 7586 20.89 kmpl
# 7587 13.58 kmpl
# 7588 23.59 kmpl
# 7589 21.21 kmpl
# 7590 17.36 kmpl
# 7591 25.1 kmpl
# 7592 23.84 kmpl
# 7593 25.83 kmpl
# 7594 19.7 kmpl
# 7595 nan
# 7596 17.09 kmpl
# 7597 18.6 kmpl
# 7598 22.0 kmpl
# 7599 20.89 kmpl
# 7600 20.52 kmpl
# 7601 25.2 kmpl
# 7602 28.4 kmpl
# 7603 28.4 kmpl
# 7604 25.17 kmpl
# 7605 15.4 kmpl
# 7606 15.1 kmpl
# 7607 25.1 kmpl
# 7608 28.4 kmpl
# 7609 22.32 kmpl
# 7610 22.07 kmpl
# 7611 22.07 kmpl
# 7612 20.92 kmpl
# 7613 27.39 kmpl
# 7614 23.59 kmpl
# 7615 16.8 kmpl
# 7616 25.4 kmpl
# 7617 23.01 kmpl
# 7618 14.0 kmpl
# 7619 20.0 kmpl
# 7620 19.3 kmpl
# 7621 17.0 kmpl
# 7622 16.47 kmpl
# 7623 17.8 kmpl
# 7624 26.0 kmpl
# 7625 17.71 kmpl
# 7626 23.9 kmpl
# 7627 16.6 kmpl
# 7628 22.77 kmpl
# 7629 17.8 kmpl
# 7630 12.99 kmpl
# 7631 14.8 kmpl
# 7632 17.3 kmpl
# 7633 14.8 kmpl
# 7634 18.7 kmpl
# 7635 18.9 kmpl
# 7636 15.37 kmpl
# 7637 26.59 kmpl
# 7638 27.28 kmpl
# 7639 16.02 kmpl
# 7640 20.54 kmpl
# 7641 15.6 kmpl
# 7642 13.2 km/kg
# 7643 22.7 kmpl
# 7644 21.1 kmpl
# 7645 19.1 kmpl
# 7646 21.5 kmpl
# 7647 21.5 kmpl
# 7648 25.32 kmpl
# 7649 19.1 kmpl
# 7650 15.96 kmpl
# 7651 nan
# 7652 22.74 kmpl
# 7653 18.2 kmpl
# 7654 23.84 kmpl
# 7655 16.36 kmpl
# 7656 24.7 kmpl
# 7657 24.7 kmpl
# 7658 21.5 kmpl
# 7659 16.1 kmpl
# 7660 15.96 kmpl
# 7661 15.04 kmpl
# 7662 18.49 kmpl
# 7663 15.04 kmpl
# 7664 19.67 kmpl
# 7665 14.3 kmpl
# 7666 12.2 kmpl
# 7667 20.77 kmpl
# 7668 23.2 kmpl
# 7669 20.77 kmpl
# 7670 23.84 kmpl
# 7671 18.9 kmpl
# 7672 23.95 kmpl
# 7673 28.4 kmpl
# 7674 15.37 kmpl
# 7675 21.1 kmpl
# 7676 19.4 kmpl
# 7677 18.9 kmpl
# 7678 18.9 kmpl
# 7679 17.3 kmpl
# 7680 20.77 kmpl
# 7681 19.3 kmpl
# 7682 24.0 kmpl
# 7683 25.1 kmpl
# 7684 16.0 kmpl
# 7685 25.0 kmpl
# 7686 28.09 kmpl
# 7687 20.37 kmpl
# 7688 18.6 kmpl
# 7689 21.4 kmpl
# 7690 25.2 kmpl
# 7691 18.9 kmpl
# 7692 24.4 kmpl
# 7693 21.43 kmpl
# 7694 18.0 kmpl
# 7695 19.7 kmpl
# 7696 19.7 kmpl
# 7697 19.7 kmpl
# 7698 13.6 kmpl
# 7699 17.01 kmpl
# 7700 13.7 kmpl
# 7701 22.37 kmpl
# 7702 19.33 kmpl
# 7703 9.5 kmpl
# 7704 16.55 kmpl
# 7705 19.16 kmpl
# 7706 18.2 kmpl
# 7707 12.99 kmpl
# 7708 19.0 kmpl
# 7709 22.48 kmpl
# 7710 15.0 kmpl
# 7711 12.83 kmpl
# 7712 17.6 kmpl
# 7713 13.5 kmpl
# 7714 18.9 kmpl
# 7715 18.15 kmpl
# 7716 12.0 kmpl
# 7717 16.5 kmpl
# 7718 18.15 kmpl
# 7719 20.51 kmpl
# 7720 17.0 kmpl
# 7721 18.9 kmpl
# 7722 23.84 kmpl
# 7723 16.2 kmpl
# 7724 21.79 kmpl
# 7725 18.9 kmpl
# 7726 25.17 kmpl
# 7727 19.87 kmpl
# 7728 18.8 kmpl
# 7729 19.7 kmpl
# 7730 nan
# 7731 20.36 kmpl
# 7732 15.4 kmpl
# 7733 21.94 km/kg
# 7734 21.1 kmpl
# 7735 16.1 kmpl
# 7736 13.93 kmpl
# 7737 18.6 kmpl
# 7738 23.95 kmpl
# 7739 18.6 kmpl
# 7740 nan
# 7741 16.1 kmpl
# 7742 21.1 kmpl
# 7743 15.0 kmpl
# 7744 16.0 kmpl
# 7745 13.55 kmpl
# 7746 12.4 kmpl
# 7747 16.55 kmpl
# 7748 12.8 kmpl
# 7749 13.0 kmpl
# 7750 23.1 kmpl
# 7751 18.15 kmpl
# 7752 22.0 kmpl
# 7753 18.06 kmpl
# 7754 20.89 kmpl
# 7755 19.81 kmpl
# 7756 19.59 kmpl
# 7757 18.12 kmpl
# 7758 17.8 kmpl
# 7759 17.0 kmpl
# 7760 24.3 kmpl
# 7761 24.3 kmpl
# 7762 20.14 kmpl
# 7763 24.3 kmpl
# 7764 22.0 kmpl
# 7765 17.3 kmpl
# 7766 21.64 kmpl
# 7767 16.0 kmpl
# 7768 19.87 kmpl
# 7769 20.73 kmpl
# 7770 19.67 kmpl
# 7771 23.01 kmpl
# 7772 15.8 kmpl
# 7773 21.56 kmpl
# 7774 19.67 kmpl
# 7775 13.22 kmpl
# 7776 20.36 kmpl
# 7777 21.1 kmpl
# 7778 17.6 kmpl
# 7779 24.7 kmpl
# 7780 12.8 kmpl
# 7781 16.55 kmpl
# 7782 15.4 kmpl
# 7783 21.27 kmpl
# 7784 12.05 kmpl
# 7785 21.5 kmpl
# 7786 25.17 kmpl
# 7787 20.3 kmpl
# 7788 20.51 kmpl
# 7789 22.1 kmpl
# 7790 19.09 kmpl
# 7791 13.1 kmpl
# 7792 12.55 kmpl
# 7793 25.4 kmpl
# 7794 28.09 kmpl
# 7795 28.4 kmpl
# 7796 24.4 kmpl
# 7797 19.7 kmpl
# 7798 15.05 kmpl
# 7799 16.8 kmpl
# 7800 25.44 kmpl
# 7801 20.4 kmpl
# 7802 21.64 kmpl
# 7803 17.1 kmpl
# 7804 20.5 kmpl
# 7805 20.54 kmpl
# 7806 22.48 kmpl
# 7807 22.71 kmpl
# 7808 11.74 kmpl
# 7809 18.0 kmpl
# 7810 17.0 kmpl
# 7811 15.73 kmpl
# 7812 20.3 kmpl
# 7813 11.79 kmpl
# 7814 17.7 kmpl
# 7815 17.3 kmpl
# 7816 25.17 kmpl
# 7817 18.8 kmpl
# 7818 15.1 kmpl
# 7819 15.1 kmpl
# 7820 16.07 kmpl
# 7821 18.9 kmpl
# 7822 16.95 kmpl
# 7823 28.4 kmpl
# 7824 19.67 kmpl
# 7825 25.2 kmpl
# 7826 26.0 kmpl
# 7827 18.9 kmpl
# 7828 22.0 kmpl
# 7829 18.6 kmpl
# 7830 22.74 kmpl
# 7831 22.7 kmpl
# 7832 19.67 kmpl
# 7833 25.4 kmpl
# 7834 15.74 kmpl
# 7835 20.14 kmpl
# 7836 18.2 kmpl
# 7837 18.9 kmpl
# 7838 13.55 kmpl
# 7839 12.8 kmpl
# 7840 13.0 kmpl
# 7841 16.55 kmpl
# 7842 24.2 kmpl
# 7843 18.15 kmpl
# 7844 15.1 kmpl
# 7845 12.8 kmpl
# 7846 nan
# 7847 21.21 kmpl
# 7848 25.17 kmpl
# 7849 20.92 kmpl
# 7850 25.17 kmpl
# 7851 24.52 kmpl
# 7852 23.95 kmpl
# 7853 15.4 kmpl
# 7854 25.83 kmpl
# 7855 19.67 kmpl
# 7856 18.2 kmpl
# 7857 24.0 kmpl
# 7858 13.6 kmpl
# 7859 22.37 kmpl
# 7860 19.33 kmpl
# 7861 14.1 kmpl
# 7862 18.0 kmpl
# 7863 19.16 kmpl
# 7864 21.79 kmpl
# 7865 27.39 kmpl
# 7866 18.2 kmpl
# 7867 12.99 kmpl
# 7868 22.0 kmpl
# 7869 16.78 kmpl
# 7870 22.0 kmpl
# 7871 24.0 kmpl
# 7872 16.78 kmpl
# 7873 16.78 kmpl
# 7874 19.0 kmpl
# 7875 14.3 kmpl
# 7876 16.8 kmpl
# 7877 17.0 kmpl
# 7878 23.4 kmpl
# 7879 18.2 kmpl
# 7880 21.1 kmpl
# 7881 25.83 kmpl
# 7882 24.29 kmpl
# 7883 22.77 kmpl
# 7884 21.19 kmpl
# 7885 21.1 kmpl
# 7886 17.8 kmpl
# 7887 15.3 kmpl
# 7888 18.16 kmpl
# 7889 20.0 kmpl
# 7890 26.59 kmpl
# 7891 23.59 kmpl
# 7892 13.68 kmpl
# 7893 14.4 kmpl
# 7894 20.3 kmpl
# 7895 14.53 kmpl
# 7896 13.5 kmpl
# 7897 24.3 kmpl
# 7898 24.52 kmpl
# 7899 24.3 kmpl
# 7900 21.1 kmpl
# 7901 23.9 kmpl
# 7902 12.99 kmpl
# 7903 19.7 kmpl
# 7904 20.77 kmpl
# 7905 25.2 kmpl
# 7906 11.36 kmpl
# 7907 22.7 kmpl
# 7908 17.8 kmpl
# 7909 21.5 kmpl
# 7910 15.37 kmpl
# 7911 25.17 kmpl
# 7912 15.3 kmpl
# 7913 15.1 km/kg
# 7914 15.0 kmpl
# 7915 24.0 kmpl
# 7916 22.54 kmpl
# 7917 15.37 kmpl
# 7918 23.0 kmpl
# 7919 14.21 kmpl
# 7920 17.6 kmpl
# 7921 21.4 kmpl
# 7922 16.25 kmpl
# 7923 25.2 kmpl
# 7924 20.52 kmpl
# 7925 13.68 kmpl
# 7926 22.95 kmpl
# 7927 19.0 kmpl
# 7928 25.2 kmpl
# 7929 20.14 kmpl
# 7930 18.0 kmpl
# 7931 12.62 kmpl
# 7932 20.4 kmpl
# 7933 24.7 kmpl
# 7934 18.49 kmpl
# 7935 16.1 kmpl
# 7936 25.4 kmpl
# 7937 27.39 kmpl
# 7938 22.0 kmpl
# 7939 27.39 kmpl
# 7940 20.36 kmpl
# 7941 23.84 kmpl
# 7942 18.6 kmpl
# 7943 21.1 kmpl
# 7944 18.15 kmpl
# 7945 12.99 kmpl
# 7946 19.6 kmpl
# 7947 25.0 kmpl
# 7948 23.65 kmpl
# 7949 12.99 kmpl
# 7950 22.0 kmpl
# 7951 15.8 kmpl
# 7952 21.7 kmpl
# 7953 21.7 kmpl
# 7954 18.5 kmpl
# 7955 22.9 kmpl
# 7956 24.7 kmpl
# 7957 17.4 kmpl
# 7958 19.7 kmpl
# 7959 21.1 kmpl
# 7960 22.32 kmpl
# 7961 25.2 kmpl
# 7962 18.16 kmpl
# 7963 20.37 kmpl
# 7964 28.09 kmpl
# 7965 19.7 kmpl
# 7966 18.49 kmpl
# 7967 16.07 kmpl
# 7968 17.8 kmpl
# 7969 12.99 kmpl
# 7970 19.6 kmpl
# 7971 25.0 kmpl
# 7972 23.65 kmpl
# 7973 12.99 kmpl
# 7974 22.0 kmpl
# 7975 15.8 kmpl
# 7976 21.7 kmpl
# 7977 21.7 kmpl
# 7978 18.5 kmpl
# 7979 22.9 kmpl
# 7980 24.7 kmpl
# 7981 17.4 kmpl
# 7982 19.7 kmpl
# 7983 21.1 kmpl
# 7984 22.32 kmpl
# 7985 25.2 kmpl
# 7986 18.16 kmpl
# 7987 20.37 kmpl
# 7988 28.09 kmpl
# 7989 18.9 kmpl
# 7990 25.0 kmpl
# 7991 16.02 kmpl
# 7992 20.77 kmpl
# 7993 20.85 kmpl
# 7994 17.7 kmpl
# 7995 16.1 kmpl
# 7996 nan
# 7997 22.74 kmpl
# 7998 24.7 kmpl
# 7999 19.7 kmpl
# 8000 20.51 kmpl
# 8001 16.6 kmpl
# 8002 21.04 kmpl
# 8003 13.4 kmpl
# 8004 24.4 kmpl
# 8005 22.0 kmpl
# 8006 25.2 kmpl
# 8007 21.9 kmpl
# 8008 23.95 kmpl
# 8009 nan
# 8010 19.81 kmpl
# 8011 22.54 kmpl
# 8012 20.0 kmpl
# 8013 27.62 kmpl
# 8014 22.9 kmpl
# 8015 27.39 kmpl
# 8016 22.3 kmpl
# 8017 17.88 kmpl
# 8018 13.93 kmpl
# 8019 18.9 kmpl
# 8020 17.2 kmpl
# 8021 17.8 kmpl
# 8022 15.96 kmpl
# 8023 11.72 kmpl
# 8024 21.1 kmpl
# 8025 16.1 kmpl
# 8026 19.09 kmpl
# 8027 20.36 kmpl
# 8028 22.74 kmpl
# 8029 18.6 kmpl
# 8030 15.3 kmpl
# 8031 18.2 kmpl
# 8032 16.5 kmpl
# 8033 22.32 kmpl
# 8034 19.01 kmpl
# 8035 24.7 kmpl
# 8036 20.51 kmpl
# 8037 19.4 kmpl
# 8038 24.52 kmpl
# 8039 20.92 kmpl
# 8040 25.4 kmpl
# 8041 18.9 kmpl
# 8042 14.8 kmpl
# 8043 14.7 kmpl
# 8044 19.7 kmpl
# 8045 19.87 kmpl
# 8046 27.3 kmpl
# 8047 17.4 kmpl
# 8048 16.47 kmpl
# 8049 18.7 kmpl
# 8050 15.9 kmpl
# 8051 17.8 kmpl
# 8052 11.1 kmpl
# 8053 17.4 kmpl
# 8054 17.8 kmpl
# 8055 18.5 kmpl
# 8056 17.8 kmpl
# 8057 11.7 kmpl
# 8058 16.6 kmpl
# 8059 15.8 kmpl
# 8060 17.8 kmpl
# 8061 17.0 kmpl
# 8062 17.8 kmpl
# 8063 14.8 kmpl
# 8064 17.8 kmpl
# 8065 18.0 kmpl
# 8066 18.0 kmpl
# 8067 13.5 kmpl
# 8068 nan
# 8069 19.0 kmpl
# 8070 25.8 kmpl
# 8071 12.8 kmpl
# 8072 20.45 kmpl
# 8073 18.9 kmpl
# 8074 16.51 kmpl
# 8075 26.21 kmpl
# 8076 14.0 kmpl
# 8077 12.8 kmpl
# 8078 18.0 kmpl
# 8079 17.0 kmpl
# 8080 11.57 kmpl
# 8081 12.0 kmpl
# 8082 17.8 kmpl
# 8083 11.5 kmpl
# 8084 18.9 kmpl
# 8085 18.3 kmpl
# 8086 23.1 kmpl
# 8087 17.57 kmpl
# 8088 20.51 kmpl
# 8089 26.0 kmpl
# 8090 20.45 kmpl
# 8091 16.0 kmpl
# 8092 22.54 kmpl
# 8093 22.32 kmpl
# 8094 13.7 kmpl
# 8095 20.0 kmpl
# 8096 17.8 kmpl
# 8097 23.0 kmpl
# 8098 17.8 kmpl
# 8099 15.1 kmpl
# 8100 21.5 kmpl
# 8101 20.3 kmpl
# 8102 22.32 kmpl
# 8103 nan
# 8104 16.9 kmpl
# 8105 13.0 kmpl
# 8106 22.32 kmpl
# 8107 20.45 kmpl
# 8108 17.8 kmpl
# 8109 24.4 kmpl
# 8110 23.1 kmpl
# 8111 23.59 kmpl
# 8112 24.4 kmpl
# 8113 12.8 kmpl
# 8114 19.7 kmpl
# 8115 16.1 kmpl
# 8116 23.95 kmpl
# 8117 26.59 kmpl
# 8118 18.5 kmpl
# 8119 20.51 kmpl
# 8120 17.92 kmpl
# 8121 18.9 kmpl
# 8122 22.54 kmpl
# 8123 18.5 kmpl
# 8124 16.8 kmpl
# 8125 19.3 kmpl
# 8126 23.57 kmpl
# 8127 23.57 kmpl

# %%
values = np.empty(len(df))

for i, value in df.mileage.items():
  try:
    splitted = value.split(" ")
  except AttributeError:
    values[i] = np.nan
  else:
    num = float(splitted[0])
    unit = splitted[1]
    if num == 0:
      new_num = np.nan
    elif unit == "kmpl":
      new_num = num * 2.35
    elif unit == "km/kg":
      new_num = num * 0.0016
    values[i] = new_num

pd.Series(values).rename("mileage_mpg").astype(np.float16)
# Out:
# 0       55.00000
# 1       49.68750
# 2       41.59375
# 3       54.06250
# 4       37.84375
#           ...
# 8123    43.46875
# 8124    39.46875
# 8125    45.34375
# 8126    55.37500
# 8127    55.37500
# Name: mileage_mpg, Length: 8128, dtype: float16

# %%
Observations:
- This is a numeric column but it is of object type
- The values are measured in 2 different units, kmpl and km/kg
- Some vehicles show a reading of 0 mileage: (maybe because)
    - The actual mileage values weren't recorded for these vehicles
    - The odometer may have been reset to zero (this is illegal)

Steps:
- We will extract the numeric values and store them as floats
- We will then convert all values to a common unit, i.e., mpg
- 1 km/l = 2.35 mpg reference
- 1 km/kg = 0.0016 mpg reference
- The values showing zero mileage will be considered missing
- Replace with nan

# %% [markdown]
# ## engine

# %%
df.engine
# Out:
# 0       1248 CC
# 1       1498 CC
# 2       1497 CC
# 3       1396 CC
# 4       1298 CC
#          ...
# 8123    1197 CC
# 8124    1493 CC
# 8125    1248 CC
# 8126    1396 CC
# 8127    1396 CC
# Name: engine, Length: 8128, dtype: object

# %%
df.engine.isna().sum()
# Out:
# 221

# %%
df.loc[df.engine.isna()]
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7846                Toyota Qualis Fleet A3  2000         200000     100000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
#         fuel seller_type transmission         owner mileage engine max_power  \
# 13    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 31    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 78    Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 87    Diesel      Dealer       Manual   First Owner     NaN    NaN       NaN
# 119   Diesel  Individual       Manual  Second Owner     NaN    NaN       NaN
# ...      ...         ...          ...           ...     ...    ...       ...
# 7846  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 7996  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8009  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8068  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 8103  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
#
#      torque  seats
# 13      NaN    NaN
# 31      NaN    NaN
# 78      NaN    NaN
# 87      NaN    NaN
# 119     NaN    NaN
# ...     ...    ...
# 7846    NaN    NaN
# 7996    NaN    NaN
# 8009    NaN    NaN
# 8068    NaN    NaN
# 8103    NaN    NaN
#
# [221 rows x 13 columns]

# %%
(
    df
    .engine
    .str.replace("CC", "")
    .astype(float)
    .describe()
)
# Out:
# count    7907.000000
# mean     1458.625016
# std       503.916303
# min       624.000000
# 25%      1197.000000
# 50%      1248.000000
# 75%      1582.000000
# max      3604.000000
# Name: engine, dtype: float64

# %%
(df
 .engine
 .str.split(" ")
 .str[0]
 .pipe(lambda ser: pd.to_numeric(ser)))
# Out:
# 0       1248.0
# 1       1498.0
# 2       1497.0
# 3       1396.0
# 4       1298.0
#          ...
# 8123    1197.0
# 8124    1493.0
# 8125    1248.0
# 8126    1396.0
# 8127    1396.0
# Name: engine, Length: 8128, dtype: float64

# %%
(df
 .engine
 .str.split(" ")
 .str[0]
 .pipe(lambda ser: pd.to_numeric(ser))
 .describe())
# Out:
# count    7907.000000
# mean     1458.625016
# std       503.916303
# min       624.000000
# 25%      1197.000000
# 50%      1248.000000
# 75%      1582.000000
# max      3604.000000
# Name: engine, dtype: float64

# %%
(df
 .engine
 .str.split(" ")
 .str[1]
 .unique())
# Out:
# array(['CC', nan], dtype=object)

# %% [markdown]
# Observations:
#         This should be a numeric column but is of object type
#         The rows which are missing values for engine, also have values missing for:
#         mileage
#         torque
#         max_power
#         seats
#         Upon inspection, these values seem to be missing due to not being recorded
#         Since these rows contain missing values in 5 columns, they could be deleted
#         Values could be imputed based on other features (multivariate imputation techniques)
#         Decision could be taken during modelling stage based on model performance
#         Otherwise, the values seem to be valid
# Steps:
#         The unit should be stripped from the values and attached to column name for better readability

# %% [markdown]
# ## max_power

# %%
df.max_power
# Out:
# 0           74 bhp
# 1       103.52 bhp
# 2           78 bhp
# 3           90 bhp
# 4         88.2 bhp
#            ...
# 8123     82.85 bhp
# 8124       110 bhp
# 8125      73.9 bhp
# 8126        70 bhp
# 8127        70 bhp
# Name: max_power, Length: 8128, dtype: object

# %%
(df
 .max_power
 .str.split(" ")
 .str[0]
 .pipe(lambda ser: pd.to_numeric(ser))
 .describe())
# Out:
# count    7912.000000
# mean       91.517919
# std        35.822499
# min         0.000000
# 25%        68.050000
# 50%        82.000000
# 75%       102.000000
# max       400.000000
# Name: max_power, dtype: float64

# %%
(df
 .max_power
 .str.split(" ")
 .str[1]
 .unique()
 )
# Out:
# array(['bhp', nan], dtype=object)

# %%
mask = np.zeros(len(df), dtype=bool)
for i, entry in df.max_power.items():
  try:
    splitted = entry.split(" ")
  except:
    mask[i] = False
  else:
    if entry.startswith("0"):
      mask[i] = True
    else:
      mask[i] = False
df[mask]
# Out:
#                                  name  year  selling_price  km_driven    fuel  \
# 575               Maruti Alto K10 LXI  2011         204999      97500  Petrol
# 576               Maruti Alto K10 LXI  2011         204999      97500  Petrol
# 1442  Maruti Swift Dzire VDI Optional  2017         589000      41232  Diesel
# 1443  Maruti Swift Dzire VDI Optional  2017         589000      41232  Diesel
# 2549   Tata Indica Vista Quadrajet LS  2012         240000      70000  Diesel
# 2550   Tata Indica Vista Quadrajet LS  2012         240000      70000  Diesel
#
#      seller_type transmission        owner mileage engine max_power torque  \
# 575   Individual       Manual  First Owner     NaN    NaN         0    NaN
# 576   Individual       Manual  First Owner     NaN    NaN         0    NaN
# 1442      Dealer       Manual  First Owner     NaN    NaN         0    NaN
# 1443      Dealer       Manual  First Owner     NaN    NaN         0    NaN
# 2549  Individual       Manual  First Owner     NaN    NaN         0    NaN
# 2550  Individual       Manual  First Owner     NaN    NaN         0    NaN
#
#       seats
# 575     NaN
# 576     NaN
# 1442    NaN
# 1443    NaN
# 2549    NaN
# 2550    NaN

# %%
df.dropna().loc[lambda df_: df_.max_power.str.startswith("0")]
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, torque, seats]
# Index: []

# %%
df.max_power.isna().sum()
# Out:
# 215

# %%
(df
 .max_power
 .str.split(" ")
 .str[0]
 .pipe(lambda ser: pd.to_numeric(ser))
 .pipe(lambda ser: ser[ser == 0]))
# Out:
# 575     0.0
# 576     0.0
# 1442    0.0
# 1443    0.0
# 2549    0.0
# 2550    0.0
# Name: max_power, dtype: float64

# %%
(df
 .max_power
 .str.split(" ")
 .str[0]
 .replace("0", np.nan)
 .pipe(lambda ser: pd.to_numeric(ser))
 .pipe(lambda ser: df.loc[ser.isna()]))
 .pipe(lambda df_: df_.loc[df_.mileage.notna()]))
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7846                Toyota Qualis Fleet A3  2000         200000     100000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
#         fuel seller_type transmission         owner mileage engine max_power  \
# 13    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 31    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 78    Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 87    Diesel      Dealer       Manual   First Owner     NaN    NaN       NaN
# 119   Diesel  Individual       Manual  Second Owner     NaN    NaN       NaN
# ...      ...         ...          ...           ...     ...    ...       ...
# 7846  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 7996  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8009  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8068  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 8103  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
#
#      torque  seats
# 13      NaN    NaN
# 31      NaN    NaN
# 78      NaN    NaN
# 87      NaN    NaN
# 119     NaN    NaN
# ...     ...    ...
# 7846    NaN    NaN
# 7996    NaN    NaN
# 8009    NaN    NaN
# 8068    NaN    NaN
# 8103    NaN    NaN
#
# [222 rows x 13 columns]

# %%
(df
 .max_power
 .str.split(" ")
 .str[0]
 .pipe(lambda ser: pd.to_numeric(ser))
 .loc[4933])
# Out:
# nan

# %%
(df
 .max_power
 .str.split(" ")
 .str[0]
 .replace("0", np.nan)
 .pipe(lambda ser: pd.to_numeric(ser)))
# Out:
# 0        74.00
# 1       103.52
# 2        78.00
# 3        90.00
# 4        88.20
#          ...
# 8123     82.85
# 8124    110.00
# 8125     73.90
# 8126     70.00
# 8127     70.00
# Name: max_power, Length: 8128, dtype: float64

# %% [markdown]
# Observations:
#         This should be a numeric column but is of object type
#         Values are measured in units of brake horsepower (bhp)
#         Entry of index 4933 has an empty value
#         Some entries have values as zero (invalid)
# Steps:
#         The unit should be stripped from the values and attached to column name for better readability
#         The values having 0 should be replaced as nan

# %% [markdown]
# ## torque

# %%
df.torque
# Out:
# 0                  190Nm@ 2000rpm
# 1             250Nm@ 1500-2500rpm
# 2           12.7@ 2,700(kgm@ rpm)
# 3        22.4 kgm at 1750-2750rpm
# 4           11.5@ 4,500(kgm@ rpm)
#                   ...
# 8123             113.7Nm@ 4000rpm
# 8124    24@ 1,900-2,750(kgm@ rpm)
# 8125               190Nm@ 2000rpm
# 8126          140Nm@ 1800-3000rpm
# 8127          140Nm@ 1800-3000rpm
# Name: torque, Length: 8128, dtype: object

# %%
df.torque.isna().sum()
# Out:
# 222

# %%
df.torque.isnull().sum()
# Out:
# 222

# %%
(
    df
    .torque
    .str.split(" ", expand=True))
# Out:
#              0                 1     2             3     4     5     6     7
# 0       190Nm@           2000rpm  None          None  None  None  None  None
# 1       250Nm@      1500-2500rpm  None          None  None  None  None  None
# 2        12.7@        2,700(kgm@  rpm)          None  None  None  None  None
# 3         22.4               kgm    at  1750-2750rpm  None  None  None  None
# 4        11.5@        4,500(kgm@  rpm)          None  None  None  None  None
# ...        ...               ...   ...           ...   ...   ...   ...   ...
# 8123  113.7Nm@           4000rpm  None          None  None  None  None  None
# 8124       24@  1,900-2,750(kgm@  rpm)          None  None  None  None  None
# 8125    190Nm@           2000rpm  None          None  None  None  None  None
# 8126    140Nm@      1800-3000rpm  None          None  None  None  None  None
# 8127    140Nm@      1800-3000rpm  None          None  None  None  None  None
#
# [8128 rows x 8 columns]

# %%
(df
 .torque
 .str.lower()
 .unique())
# Out:
# array(['190nm@ 2000rpm', '250nm@ 1500-2500rpm', '12.7@ 2,700(kgm@ rpm)',
#        '22.4 kgm at 1750-2750rpm', '11.5@ 4,500(kgm@ rpm)',
#        '113.75nm@ 4000rpm', '7.8@ 4,500(kgm@ rpm)', '59nm@ 2500rpm',
#        '170nm@ 1800-2400rpm', '160nm@ 2000rpm', '248nm@ 2250rpm',
#        '78nm@ 4500rpm', nan, '84nm@ 3500rpm', '115nm@ 3500-3600rpm',
#        '200nm@ 1750rpm', '62nm@ 3000rpm', '219.7nm@ 1500-2750rpm',
#        '114nm@ 3500rpm', '115nm@ 4000rpm', '69nm@ 3500rpm',
#        '172.5nm@ 1750rpm', '6.1kgm@ 3000rpm', '114.7nm@ 4000rpm',
#        '60nm@ 3500rpm', '90nm@ 3500rpm', '151nm@ 4850rpm',
#        '104nm@ 4000rpm', '320nm@ 1700-2700rpm', '250nm@ 1750-2500rpm',
#        '145nm@ 4600rpm', '146nm@ 4800rpm', '343nm@ 1400-3400rpm',
#        '200nm@ 1400-3400rpm', '200nm@ 1250-4000rpm',
#        '400nm@ 2000-2500rpm', '138nm@ 4400rpm', '360nm@ 1200-3400rpm',
#        '200nm@ 1200-3600rpm', '380nm@ 1750-2500rpm', '173nm@ 4000rpm',
#        '400nm@ 1750-3000rpm', '400nm@ 1400-2800rpm',
#        '200nm@ 1750-3000rpm', '111.7nm@ 4000rpm', '219.6nm@ 1500-2750rpm',
#        '112nm@ 4000rpm', '250nm@ 1500-3000rpm', '130nm@ 4000rpm',
#        '205nm@ 1750-3250rpm', '280nm@ 1350-4600rpm', '99.04nm@ 4500rpm',
#        '77nm@ 3500rpm', '110nm@ 3750rpm', '153nm@ 3800rpm',
#        '113.7nm@ 4000rpm', '114nm@ 4000rpm', '113nm@ 4200rpm',
#        '101nm@ 3000rpm', '290nm@ 1800-2800rpm', '120nm@ 4250rpm',
#        '250nm@ 1500~4500rpm', '96 nm at 3000 rpm', '360nm@ 1750-2800rpm',
#        '135nm@ 2500rpm', '259.8nm@ 1900-2750rpm', '200nm@ 1900rpm',
#        '259.9nm@ 1900-2750rpm', '91nm@ 4250rpm', '96.1nm@ 3000rpm',
#        '109nm@ 4500rpm', '202nm@ 3600-5200rpm', '430nm@ 1750-2500rpm',
#        '347nm@ 4300rpm', '382nm@ 1750-2250rpm', '620nm@ 1600-2400rpm',
#        '400nm@ 1750-2500rpm', '250@ 1250-5000rpm', '500nm@ 1600-1800rpm',
#        '250nm@ 1600-3600rpm', '400nm', '550nm@ 1750-2750rpm',
#        '490nm@ 1600rpm', '250 nm at 2750 rpm', '177.5nm@ 4700rpm',
#        '170nm@ 1750-4000rpm', '300nm@ 1200-4000rpm',
#        '300nm@ 1200-1400rpm', '260nm@ 1500-2750rpm', '213nm@ 4500rpm',
#        '224nm@ 4000rpm', '640nm@ 1740rpm', '113nm@ 4500rpm',
#        '95nm@ 3000-4300rpm', '13.1kgm@ 4600rpm', '205nm@ 1800-2800rpm',
#        '71nm@ 3500rpm', '190nm@ 1750-3000rpm', '146nm at 4800 rpm',
#        '14.9 kgm at 3000 rpm', '115nm@ 3200rpm', '117nm@ 4000rpm',
#        '320nm@ 1500-3000rpm', '72nm@ 4386rpm', '11.4 kgm at 4,000 rpm',
#        '140nm@ 1500-4000rpm', '134nm@ 4000rpm', '150nm@ 4500rpm',
#        '340nm@ 1800-3250rpm', '240nm@ 1600-2800rpm',
#        '330nm@ 1600-2800rpm', '12.5@ 3,500(kgm@ rpm)', '110nm@ 4800rpm',
#        '111.8nm@ 4000rpm', '11.8@ 3,200(kgm@ rpm)', '135.4nm@ 2500rpm',
#        '300nm@ 1750-2500rpm', '190.25nm@ 1750-2250rpm',
#        '140nm@ 1800-3000rpm', '20.4@ 1400-3400(kgm@ rpm)',
#        '247nm@ 1800-2000rpm', '223nm@ 1600-2200rpm',
#        '180 nm at 1440-1500rpm', '195nm@ 1400-2200rpm',
#        '154.9nm@ 4200rpm', '114.73nm@ 4000rpm', '160nm@ 1500-2750rpm',
#        '108nm@ 4400rpm', '190.24nm@ 1750-2250rpm', '200nm@ 2000-3500rpm',
#        '420nm@ 1400-2600rpm', '100nm@ 2700rpm', '51nm@ 4000rpm',
#        '250nm@ 1250-5300rpm', '132nm@ 3000rpm', '350nm@ 1500-2750rpm',
#        '218nm@ 4200rpm', '14.9@ 3,000(kgm@ rpm)',
#        '24@ 1,900-2,750(kgm@ rpm)', '13.5@ 2,500(kgm@ rpm)',
#        '85nm@ 3000rpm', '74.5nm@ 4000rpm', '160nm@ 1750rpm',
#        '180.4nm@ 1750-2500rpm', '230nm@ 1500-2500rpm',
#        '219.66nm@ 1500-2750rpm', '245nm@ 1750rpm', '360nm@ 1400-3200rpm',
#        '320nm@ 2000rpm', '135 nm at 2500  rpm ',
#        '24 kgm at 1900-2750 rpm', '190nm@ 1750-2250rpm',
#        '204nm@ 2000-2750rpm', '14.3@ 1,800-3,000(kgm@ rpm)',
#        '250nm@ 1500-2750rpm', '125nm@ 2000rpm', '172nm@ 4300rpm',
#        '150nm@ 1750rpm', '102nm@ 4000rpm', '85nm@ 2500rpm',
#        '8.5@ 2,500(kgm@ rpm)', '180nm@ 1440-1500rpm', '106.5nm@ 4400rpm',
#        '108.5nm@ 5000rpm', '350nm@ 1750-2500rpm', '144.15nm@ 4500rpm',
#        '104nm@ 4400rpm', '99nm@ 4500rpm', '200nm@ 2000rpm',
#        '280nm@ 1800-2800rpm', '142.5nm@ 1750rpm', '140nm@ 4400rpm',
#        '115@ 2,500(kgm@ rpm)', '196nm@ 5000rpm',
#        '260 nm at 1800-2200 rpm', '9.8@ 3,000(kgm@ rpm)',
#        '209nm@ 2000rpm', '135 nm at 2500 rpm', '140nm@ 4200rpm',
#        '220nm at 1400-2600 rpm', '48nm@ 3000rpm', '171nm@ 1800rpm',
#        '277.5nm@ 1700-2200rpm', '215nm@ 3600rpm', '219.6nm@ 1750-2750rpm',
#        '195nm@ 1440-2200rpm', '13@ 2,500(kgm@ rpm)', '180nm@ 2000rpm',
#        '200nm@ 1400-2200rpm', '380nm(38.7kgm)@ 2500rpm', '110nm@ 4400rpm',
#        '72nm@ 4388rpm', '263.7nm@ 2500rpm', '320nm@ 1600-2800rpm',
#        '25.5@ 1,500-3,000(kgm@ rpm)', '16.3@ 2,000(kgm@ rpm)',
#        '190 nm at 1750 rpm ', '94.14nm@ 3500rpm', '12@ 3,500(kgm@ rpm)',
#        '113nm@ 5000rpm', '280nm@ 2400-2800rpm', '96nm@ 3500rpm',
#        '16@ 2,000(kgm@ rpm)', '320nm@ 1750-3000rpm',
#        '320nm@ 1750-2500rpm', '190nm@ 1750rpm', '789nm@ 2250rpm',
#        '259.87nm@ 1900-2750rpm', '205nm@ 1750rpm',
#        '436.39nm@ 1800-2500rpm', '182.5nm@ 1500-1800rpm',
#        '90.3nm@ 4200rpm', '12.5@ 2,500(kgm@ rpm)', '215nm@ 1750-3000rpm',
#        '215nm@ 1750-3000', '305nm@ 2000rpm', '540nm@ 2000rpm',
#        '327nm@ 2600rpm', '300nm@ 1600-3000rpm', '620nm@ 2000-2500rpm',
#        '450nm@ 1600-2400rpm', '19@ 1,800(kgm@ rpm)',
#        '9.2@ 4,200(kgm@ rpm)', '145@ 4,100(kgm@ rpm)',
#        '51nm@ 4000+/-500rpm', '110nm@ 3000rpm', '148nm@ 3500rpm',
#        '116nm@ 4750rpm', '48@ 3,000+/-500(nm@ rpm)', '148nm@ 4000rpm',
#        '222nm@ 4300rpm', '135.3nm@ 5000rpm', '98nm@ 1600-3000rpm',
#        '170nm@ 1400-4500rpm', '343nm@ 1400-2800rpm',
#        '402nm@ 1600-3000rpm', '113nm@ 3300rpm', '99.07nm@ 4500rpm',
#        '210nm@ 1600-2200rpm', '190 nm at 1750  rpm ', '32.1kgm@ 2000rpm',
#        '224nm@ 1500-2750rpm', '215nm@ 1750-2500rpm',
#        '25@ 1,800-2,800(kgm@ rpm)', '197nm@ 1750rpm', '136.3nm@ 4200rpm',
#        '470nm@ 1750-2500rpm', '11@ 3,000(kgm@ rpm)', '142nm@ 4000rpm',
#        '145nm@ 4100rpm', '320nm@ 1500-2800rpm', '123nm@ 1000-2500rpm',
#        '218nm@ 1400-2600rpm', '510@ 1600-2400', '220nm@ 1500-2750rpm',
#        '380nm@ 2000rpm', '104nm@ 3100rpm', '292nm@ 2000rpm',
#        '20@ 3,750(kgm@ rpm)', '46.5@ 1,400-2,800(kgm@ rpm)',
#        '380nm@ 2500rpm', '15@ 3,800(kgm@ rpm)', '136nm@ 4250rpm',
#        '228nm@ 4400rpm', '149nm@ 4500rpm', '187nm@ 2500rpm',
#        '146nm@ 3400rpm', '8.6@ 3,500(kgm@ rpm)', '219.7nm@ 1750-2750rpm',
#        '190nm@ 2000-3000', '450nm@ 2000rpm', '300nm@ 2000rpm',
#        '230nm@ 1800-2000rpm', '42@ 2,000(kgm@ rpm)',
#        '110nm@ 3000-4300rpm', '110(11.2)@ 4800', '330nm@ 1800rpm',
#        '225nm@ 1500-2500rpm', '380nm@ 1750-2750rpm',
#        '28.3@ 1,700-2,200(kgm@ rpm)', '259.88nm@ 1900-2750rpm',
#        '580nm@ 1400-3250rpm', '400 nm /2000 rpm', '127nm@ 3500rpm',
#        '300nm@ 1500-2500rpm', '132.3nm@ 4000rpm', '113nm@ 4400rpm',
#        '153nm@ 3750-3800rpm', '10.7@ 2,500(kgm@ rpm)', '124.6nm@ 3500rpm',
#        '78nm@ 3500rpm', '219.9nm@ 1750-2750rpm', '420.7nm@ 1800-2500rpm',
#        '130nm@ 3000rpm', '424nm@ 2000rpm', '130@ 2500(kgm@ rpm)',
#        '99.8nm@ 2700rpm', '113nm@ 4,500rpm', '11.2@ 4,400(kgm@ rpm)',
#        '240nm@ 1850rpm', '16.1@ 4,200(kgm@ rpm)', '320nm@ 1750-2700rpm',
#        '115nm@ 4500rpm', '245nm@ 4000rpm', '321nm@ 1600-2400rpm',
#        '619nm@ 1600-2400rpm', '380nm@ 1750-3000rpm', '560nm@ 1500rpm',
#        '230nm@ 1500-2250rpm', '90nm@ 2650rpm', '260nm@ 1800-2200rpm',
#        '600nm@ 2000rpm', '259.87nm@ 1500-3000rpm',
#        '16.6@ 4,500(kgm@ rpm)', '12.5@ 3,000(kgm@ rpm)',
#        '620nm@ 1500-2500rpm', '250nm@ 1500-4500rpm',
#        '14.9@ 3,400(kgm@ rpm)', '25.5@ 1,900(kgm@ rpm)',
#        '33.7@ 1,800(kgm@ rpm)', '285nm@ 2400-4000rpm',
#        '10.7@ 2,600(kgm@ rpm)', '250nm@ 1000-2000rpm', '240nm@ 1750rpm',
#        '226nm@ 4400rpm', '510nm@ 1600-2800rpm', '155 nm at 1600-2800 rpm',
#        '240nm@ 2000rpm', '103nm@ 4500rpm', '13.5@ 4,800(kgm@ rpm)',
#        '400nm@ 1750-2750rpm', '175nm@ 1500-4100rpm', '72.9nm@ 2250rpm',
#        '135.4nm@ 2500', '245nm@ 5000rpm', '57nm@ 2500rpm',
#        '96nm@ 2500rpm', '10.4@ 3,200(kgm@ rpm)', '128nm@ 3100rpm',
#        '102nm@ 2600rpm', '131nm@ 4400rpm', '11.4@ 4,000(kgm@ rpm)',
#        '250nm@ 4250rpm', '343nm@ 1600-2800rpm', '185nm@ 1750-2750rpm',
#        '12@ 2500(kgm@ rpm)', '12.4@ 2,600(kgm@ rpm)', '170nm@ 4200rpm',
#        '176nm@ 1500rpm', '380nm@ 1800-2800rpm', '250nm@ 1600-2000rpm',
#        '24.5@ 3,500-4,500(kgm@ rpm)', '22.9@ 1,950-4,700(kgm@ rpm)',
#        '121nm@ 2800rpm', '210 / 1900', '250nm@ 1250-5000rpm',
#        '400nm@ 175-2750rpm', '350nm@ 1500-3500rpm', '175nm@ 1750-4000rpm',
#        '115@ 2500(kgm@ rpm)', '110nm@ 4500rpm', '190nm@ 2000-3000rpm',
#        '106nm@ 2200rpm', '21.4@ 1,750-4,600(kgm@ rpm)', '96nm@ 3000rpm',
#        '23.6@ 4,250(kgm@ rpm)', '11.3kgm@ 4700rpm', '450nm@ 1750-2500rpm',
#        '35.7@ 1,750-3,000(kgm@ rpm)', '6@ 2,500(kgm@ rpm)',
#        '13.9 kgm at 4200 rpm', '320nm@ 1400-4100rpm',
#        '150nm@ 1700-4500rpm', '113.8nm@ 4000rpm', '110@ 3,000(kgm@ rpm)',
#        '151nm@ 2400rpm', '62nm@ 2500rpm', '18@ 1,600-2,200(kgm@ rpm)',
#        '83nm@ 3000rpm', '124.5nm@ 3500rpm', '20@ 4,700(kgm@ rpm)',
#        '300nm@ 1600-4000rpm', '171.6nm@ 1500-4000rpm',
#        '21.4@ 1,900(kgm@ rpm)', '190@ 21,800(kgm@ rpm)',
#        '5.7@ 2,500(kgm@ rpm)', '88.4nm@ 4200rpm',
#        '250 nm at 1,500-3,000 rpm', '340nm@ 1750-3000rpm',
#        '36.6@ 1,750-2,500(kgm@ rpm)', '12.5kgm@ 3500rpm',
#        '6.1@ 3,000(kgm@ rpm)', '110nm@ 4000rpm', '350nm@ 1800-2600rpm',
#        '4.8kgm@ 3000rpm', '355nm@ 4500rpm', '51@ 1,750-3,000(kgm@ rpm)',
#        '119nm@ 4250rpm', '410nm@ 1600-2800rpm', '174nm@ 4300rpm',
#        '99.1nm@ 4500rpm', '385nm@ 1600-2500rpm', '180 nm at 2000rpm',
#        '190 nm at 1750 rpm', '53@ 2,000-2,750(kgm@ rpm)',
#        '360nm@ 1400-2600rpm', '420nm@ 2000rpm', '124nm@ 3500rpm',
#        '17.5@ 4,300(kgm@ rpm)', '360nm@ 2000rpm', '145nm@ 3750rpm',
#        '85nm@ 3500rpm', '190nm@ 4200rpm', '190 nm at 2000rpm',
#        '13.5@ 2500(kgm@ rpm)', '159.8nm@ 1500-2750rpm', '500nm@ 2000rpm',
#        '333nm@ 1600-3200rpm', '400nm@ 2800rpm',
#        '33@ 2,000-2,680(kgm@ rpm)', '10.2@ 2,600(kgm@ rpm)', '480nm',
#        '190nm@ 4300rpm', '320nm@ 1800-2800rpm', '380nm@ 1750rpm',
#        '250.06nm@ 1500-2750rpm', '190nm@ 3700rpm',
#        '436.4nm@ 1800-2500rpm', '96  nm at 3000  rpm '], dtype=object)

# %%
(df
 .torque
 .str.extract(r"(^[0-9.]+).", expand=False)
 .pipe(lambda ser: pd.to_numeric(ser)))
# Out:
# 0       190.0
# 1       250.0
# 2        12.7
# 3        22.4
# 4        11.5
#         ...
# 8123    113.7
# 8124     24.0
# 8125    190.0
# 8126    140.0
# 8127    140.0
# Name: torque, Length: 8128, dtype: float64

# %%
(df
 .torque
 .str.extract(r"(^[0-9.]+).", expand=False)
 .pipe(lambda ser: pd.to_numeric(ser))
 .values)
# Out:
# array([190. , 250. ,  12.7, ..., 190. , 140. , 140. ])

# %%
values = (df
          .torque
          .str.extract(r"(^[0-9.]+).", expand=False)
          .pipe(lambda ser: pd.to_numeric(ser))
          .values)

for i, entry in (df
                 .torque
                 .str.lower()
                 .items()):
  try:
    splitted = entry.split(" ")
  except AttributeError:
    pass
  else:
    if "nm" in entry:
      pass
    elif "kg" in entry:
      values[i] = values[i] * 9.80665

(pd.Series(values)
   .rename("torque_nm")
   .pipe(lambda ser: pd.concat([df.torque, ser], axis=1)))
# Out:
#                          torque   torque_nm
# 0                190Nm@ 2000rpm  190.000000
# 1           250Nm@ 1500-2500rpm  250.000000
# 2         12.7@ 2,700(kgm@ rpm)  124.544455
# 3      22.4 kgm at 1750-2750rpm  219.668960
# 4         11.5@ 4,500(kgm@ rpm)  112.776475
# ...                         ...         ...
# 8123           113.7Nm@ 4000rpm  113.700000
# 8124  24@ 1,900-2,750(kgm@ rpm)  235.359600
# 8125             190Nm@ 2000rpm  190.000000
# 8126        140Nm@ 1800-3000rpm  140.000000
# 8127        140Nm@ 1800-3000rpm  140.000000
#
# [8128 rows x 2 columns]

# %% [markdown]
# Observations:
#         This should be nuemric column but is of object type
#         The values are listed mainly in 2 units: kgm and Nm
#         The units are very messy and inconsistent
# Steps:
#         The unit should be stripped from the values and attached to column name for better readability
#         The values will all be converted to a common unit of Nm
#         1 kgm = 9.80665 Nm reference

# %% [markdown]
# ## seats

# %%
df.seats
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 8123    5.0
# 8124    5.0
# 8125    5.0
# 8126    5.0
# 8127    5.0
# Name: seats, Length: 8128, dtype: float64

# %%
df.seats.unique()
# Out:
# array([ 5.,  4., nan,  7.,  8.,  6.,  9., 10., 14.,  2.])

# %%
df.seats.isna().sum()
# Out:
# 221

# %%
df.loc[df.seats.isna()]
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7846                Toyota Qualis Fleet A3  2000         200000     100000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
#         fuel seller_type transmission         owner mileage engine max_power  \
# 13    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 31    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 78    Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 87    Diesel      Dealer       Manual   First Owner     NaN    NaN       NaN
# 119   Diesel  Individual       Manual  Second Owner     NaN    NaN       NaN
# ...      ...         ...          ...           ...     ...    ...       ...
# 7846  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 7996  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8009  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8068  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 8103  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
#
#      torque  seats
# 13      NaN    NaN
# 31      NaN    NaN
# 78      NaN    NaN
# 87      NaN    NaN
# 119     NaN    NaN
# ...     ...    ...
# 7846    NaN    NaN
# 7996    NaN    NaN
# 8009    NaN    NaN
# 8068    NaN    NaN
# 8103    NaN    NaN
#
# [221 rows x 13 columns]

# %%
df.seats.value_counts()
# Out:
# seats
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: count, dtype: int64

# %% [markdown]
# Observations:
#         This column seems to be valid
#         Its of type float due to missing values
#         No further cleaning required

# %% [markdown]
# # Data Cleaning Function

# %%
def clean_data(data):
  # this function takes in the dataset and returns the cleaned version

  def convert_mileage_mpg(ser):
    # this function takes in the mileage column
    # and returns all values in the unit of mpg

    new_values = np.empty(len(ser))
    for i, entry in ser.items():
      try:
        splitted = entry.split(" ")
      except AttributeError:
        new_values[i] = np.nan
      else:
        value = float(splitted[0])
        unit = splitted[1]
        if num == 0:
          new_values[i] = np.nan
        elif unit == "kmpl":
          new_values[i] = value * 2.35
        elif unit == "km/kg":
          new_values[i] = value * 0.0016
    return (pd.Series(new_values)
              .astype(np.float16))


  def convert_torque_nm(ser):
    # this function takes in the torque column
    # and returns all values in unit of Nm

    values = (ser
              .str.extract(r"(^[0-9.]+).", expand=False)
              .pipe(lambda ser: pd.to_numeric(ser))
              .values)
    for i, entry in (ser
                     .str.lower()
                     .items()):
      try:
        # to handle nan values
        entry.split(" ")
      except AttributeError:
        pass
      else:
        if "nm" in entry:
          pass
        elif "kg" in entry:
          values[i] = values[i] * 9.80665
    return pd.Series(values)


  return (data
          .drop_duplicates(ignore_index=True)
          .apply(lambda ser: ser.str.strip() if ser.dtype == "object" else ser)
          .pipe(lambda df_: pd.concat([df_
                                       .name
                                       .str.split(" ", n=2, expand=True)
                                       .set_axis(["company", "model", "edition"], axis=1),
                                       df_],
                                      axis=1))
          .assign(year=lambda df_: df_.year.astype(np.int16),
                  fuel=lambda df_: df_.fuel.astype("category"),
                  seller_type=lambda df_: df_.seller_type.astype("category"),
                  transmission=lambda df_: df_.transmission.astype("category"),
                  owner=lambda df_: df_.owner
                                       .str.replace(" Owner", "")
                                       .astype("category"),
                  mileage_mpg=lambda df_: convert_mileage_mpg(df_.mileage),
                  engine_cc=lambda df_: df_
                                         .engine
                                         .str.split(" ")
                                         .str[0]
                                         .pipe(lambda ser: pd.to_numeric(ser)),
                  max_power_bhp=lambda df_: df_
                                             .max_power
                                             .str.split(" ")
                                             .str[0]
                                             .replace("0", np.nan)
                                             .pipe(lambda ser: pd.to_numeric(ser,
                                                                             errors="coerce")),
                  torque_nm=lambda df_: convert_torque_nm(df_.torque))
          .drop(columns=["mileage", "engine", "max_power", "torque"])
          .reindex(columns=["name",
                            "company",
                            "model",
                            "edition",
                            "year",
                            "owner",
                            "fuel",
                            "seller_type",
                            "transmission",
                            "km_driven",
                            "mileage_mpg",
                            "engine_cc",
                            "max_power_bhp",
                            "torque_nm",
                            "seats",
                            "selling_price"]))

# %% [markdown]
# # Cleaned Data

# %%
df_cleaned = clean_data(df)
df_cleaned
# Out:
#                                    name  company  model               edition  \
# 0                Maruti Swift Dzire VDI   Maruti  Swift             Dzire VDI
# 1          Skoda Rapid 1.5 TDI Ambition    Skoda  Rapid      1.5 TDI Ambition
# 2              Honda City 2017-2020 EXi    Honda   City         2017-2020 EXi
# 3             Hyundai i20 Sportz Diesel  Hyundai    i20         Sportz Diesel
# 4                Maruti Swift VXI BSIII   Maruti  Swift             VXI BSIII
# ...                                 ...      ...    ...                   ...
# 6921  Maruti Wagon R VXI BS IV with ABS   Maruti  Wagon  R VXI BS IV with ABS
# 6922         Hyundai i20 Magna 1.4 CRDi  Hyundai    i20        Magna 1.4 CRDi
# 6923                  Hyundai i20 Magna  Hyundai    i20                 Magna
# 6924              Hyundai Verna CRDi SX  Hyundai  Verna               CRDi SX
# 6925             Maruti Swift Dzire ZDi   Maruti  Swift             Dzire ZDi
#
#       year           owner    fuel seller_type transmission  km_driven  \
# 0     2014           First  Diesel  Individual       Manual     145500
# 1     2014          Second  Diesel  Individual       Manual     120000
# 2     2006           Third  Petrol  Individual       Manual     140000
# 3     2010           First  Diesel  Individual       Manual     127000
# 4     2007           First  Petrol  Individual       Manual     120000
# ...    ...             ...     ...         ...          ...        ...
# 6921  2013          Second  Petrol  Individual       Manual      50000
# 6922  2014          Second  Diesel  Individual       Manual      80000
# 6923  2013           First  Petrol  Individual       Manual     110000
# 6924  2007  Fourth & Above  Diesel  Individual       Manual     119000
# 6925  2009           First  Diesel  Individual       Manual     120000
#
#       mileage_mpg  engine_cc  max_power_bhp   torque_nm  seats  selling_price
# 0        55.00000     1248.0          74.00  190.000000    5.0         450000
# 1        49.68750     1498.0         103.52  250.000000    5.0         370000
# 2        41.59375     1497.0          78.00  124.544455    5.0         158000
# 3        54.06250     1396.0          90.00  219.668960    5.0         225000
# 4        37.84375     1298.0          88.20  112.776475    5.0         130000
# ...           ...        ...            ...         ...    ...            ...
# 6921     44.40625      998.0          67.10   90.000000    5.0         260000
# 6922     52.96875     1396.0          88.73  219.700000    5.0         475000
# 6923     43.46875     1197.0          82.85  113.700000    5.0         320000
# 6924     39.46875     1493.0         110.00  235.359600    5.0         135000
# 6925     45.34375     1248.0          73.90  190.000000    5.0         382000
#
# [6926 rows x 16 columns]

# %% [markdown]
# # Memory Comparison

# %%
df.memory_usage(deep=True).sum()
# Out:
# 5203003

# %%
df_cleaned.memory_usage(deep=True).sum()
# Out:
# 2302783

# %% [markdown]
# Final Remarks:
#     The dataset is now cleaned and ready for further exploratory data analysis
#     The cleaned dataset utilizes nearly 2.25 times less memory than the original dataset
#     The name column was split into 3 parts:
#     Further analysis should be done if it needs to be split into 2 or 3 parts for better model performance
#     The columns measuring mileage, max_power, torque, seats and engine have values missing in the same rows
#     These rows could be deleted, or
#     Imputed based on other features (depending on model performance)
#     Some columns contain very rare categories (<1% of total observations)
#     These categories should be handled appropriately

# %%
df_cleaned.to_csv("car_details_cleaned.csv", index=False)

# %%
pd.read_csv("car_details_cleaned.csv")
# Out:
#                                    name  company  model               edition  \
# 0                Maruti Swift Dzire VDI   Maruti  Swift             Dzire VDI
# 1          Skoda Rapid 1.5 TDI Ambition    Skoda  Rapid      1.5 TDI Ambition
# 2              Honda City 2017-2020 EXi    Honda   City         2017-2020 EXi
# 3             Hyundai i20 Sportz Diesel  Hyundai    i20         Sportz Diesel
# 4                Maruti Swift VXI BSIII   Maruti  Swift             VXI BSIII
# ...                                 ...      ...    ...                   ...
# 6921  Maruti Wagon R VXI BS IV with ABS   Maruti  Wagon  R VXI BS IV with ABS
# 6922         Hyundai i20 Magna 1.4 CRDi  Hyundai    i20        Magna 1.4 CRDi
# 6923                  Hyundai i20 Magna  Hyundai    i20                 Magna
# 6924              Hyundai Verna CRDi SX  Hyundai  Verna               CRDi SX
# 6925             Maruti Swift Dzire ZDi   Maruti  Swift             Dzire ZDi
#
#       year           owner    fuel seller_type transmission  km_driven  \
# 0     2014           First  Diesel  Individual       Manual     145500
# 1     2014          Second  Diesel  Individual       Manual     120000
# 2     2006           Third  Petrol  Individual       Manual     140000
# 3     2010           First  Diesel  Individual       Manual     127000
# 4     2007           First  Petrol  Individual       Manual     120000
# ...    ...             ...     ...         ...          ...        ...
# 6921  2013          Second  Petrol  Individual       Manual      50000
# 6922  2014          Second  Diesel  Individual       Manual      80000
# 6923  2013           First  Petrol  Individual       Manual     110000
# 6924  2007  Fourth & Above  Diesel  Individual       Manual     119000
# 6925  2009           First  Diesel  Individual       Manual     120000
#
#       mileage_mpg  engine_cc  max_power_bhp   torque_nm  seats  selling_price
# 0           55.00     1248.0          74.00  190.000000    5.0         450000
# 1           49.70     1498.0         103.52  250.000000    5.0         370000
# 2           41.60     1497.0          78.00  124.544455    5.0         158000
# 3           54.06     1396.0          90.00  219.668960    5.0         225000
# 4           37.84     1298.0          88.20  112.776475    5.0         130000
# ...           ...        ...            ...         ...    ...            ...
# 6921        44.40      998.0          67.10   90.000000    5.0         260000
# 6922        52.97     1396.0          88.73  219.700000    5.0         475000
# 6923        43.47     1197.0          82.85  113.700000    5.0         320000
# 6924        39.47     1493.0         110.00  235.359600    5.0         135000
# 6925        45.34     1248.0          73.90  190.000000    5.0         382000
#
# [6926 rows x 16 columns]
